# %%
import pandas as pd
import numpy as np
import csv

# %%
cali_layoffs = pd.read_csv('california_warn_raw.csv')
cali_population = pd.read_csv('county_population.csv', delimiter='\t', thousands=',')

# %% [markdown]
# population data from: https://www.census.gov/data/tables/time-series/demo/popest/2010s-counties-total.html#par_textimage_242301767

# %%
cali_layoffs.head()
# Out:
#   Notice Date Effective Date Received Date                          Company  \
# 0  10/26/2020     12/28/2020    11/10/2020               DAMAC Products LLC
# 1  10/27/2020     12/31/2020    11/10/2020                       Gulfstream
# 2  10/26/2020     12/16/2020    11/10/2020  Renaissance Newport Beach Hotel
# 3  10/01/2020     10/05/2020    11/10/2020                 Howmet Aerospace
# 4  10/26/2020     07/07/2020    11/10/2020        Newport Diversified, Inc.
#
#                City                  County  Employees     Layoff/Closure
# 0         La Mirada     Los Angeles County        79.0  Closure Permanent
# 1        Long Beach     Los Angeles County       608.0  Closure Permanent
# 2     Newport Beach          Orange County       104.0  Closure Permanent
# 3  Rancho Cucamonga  San Bernardino County        66.0   Layoff Temporary
# 4          El Cajon       San Diego County        91.0   Layoff Temporary

# %%
cali_layoffs.tail()
# Out:
#      Notice Date Effective Date Received Date  \
# 9502  06/25/2015     08/24/2015    06/30/2015
# 9503  06/25/2015     08/24/2015    06/30/2015
# 9504  06/25/2015     08/24/2015    06/30/2015
# 9505  06/29/2015     08/28/2015    06/30/2015
# 9506  06/30/2015     07/22/2015    06/30/2015
#
#                                Company           City          County  \
# 9502                      Intuit, Inc.  San Francisco  No County Name
# 9503                      Intuit, Inc.   Santa Monica  No County Name
# 9504                      Intuit, Inc.         Venice  No County Name
# 9505                     Safeway, Inc.     Pleasanton  No County Name
# 9506  Medtronic Ablation Frontiers LLC       Carlsbad  No County Name
#
#       Employees               Layoff/Closure
# 9502       86.0             Layoff Permanent
# 9503       49.0            Closure Permanent
# 9504       11.0            Closure Permanent
# 9505       18.0  Layoff Unknown at this time
# 9506       50.0            Closure Permanent

# %% [markdown]
# ## California Layoffs
#
# For the purposes of this analysis, we are selecting 2020 records by isolating the year on the `Notice date` column.
# By choosing `Notice date` we make sure that these layoffs were issued after the start of shelter in place for 2020, as some layoff notices can be issues much earlier the layoff date.

# %%
cali_layoffs['Year'] = cali_layoffs['Notice Date'].str[-4:]
cali_layoffs['Layoff/Closure'] = cali_layoffs['Layoff/Closure'].str.replace('at thistime', 'at this time')
cali_layoffs['County'] = cali_layoffs['County'].str.strip()
cali_layoffs.loc[~(cali_layoffs['County'].str.endswith('County')),'County'] = cali_layoffs['County'] + " County"
cali_2020 = cali_layoffs[cali_layoffs['Year'] == '2020']
cali_2020['Employees'] = cali_2020['Employees'].astype('Int64')
cali_2020.tail()
# Out:
# <ipython-input-5-ab5b9e906f9a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cali_2020['Employees'] = cali_2020['Employees'].astype('Int64')
#      Notice Date Effective Date Received Date  \
# 5636  01/03/2020     03/06/2020    01/09/2020
# 5637  01/06/2020     03/07/2020    01/08/2020
# 5638  01/06/2020     03/09/2020    01/06/2020
# 5639  01/03/2020     03/04/2020    01/03/2020
# 5640  01/03/2020     03/04/2020    01/03/2020
#
#                                   Company                   City  \
# 5636                      Medtronic, Inc.                 Goleta
# 5637                    Edmunds.com, Inc.           Santa Monica
# 5638  SunSelect Produce (California) Inc.              Tehachapi
# 5639               Aramark Services, Inc.                Anaheim
# 5640               Aramark Services, Inc.  Rancho SantaMargarita
#
#                     County  Employees     Layoff/Closure  Year
# 5636  Santa Barbara County         33   Layoff Permanent  2020
# 5637    Los Angeles County        122   Layoff Permanent  2020
# 5638           Kern County        236  Closure Permanent  2020
# 5639         Orange County          9  Closure Permanent  2020
# 5640         Orange County         13  Closure Permanent  2020

# %%
cali_layoffs.tail()
# Out:
#      Notice Date Effective Date Received Date  \
# 9502  06/25/2015     08/24/2015    06/30/2015
# 9503  06/25/2015     08/24/2015    06/30/2015
# 9504  06/25/2015     08/24/2015    06/30/2015
# 9505  06/29/2015     08/28/2015    06/30/2015
# 9506  06/30/2015     07/22/2015    06/30/2015
#
#                                Company           City                 County  \
# 9502                      Intuit, Inc.  San Francisco  No County Name County
# 9503                      Intuit, Inc.   Santa Monica  No County Name County
# 9504                      Intuit, Inc.         Venice  No County Name County
# 9505                     Safeway, Inc.     Pleasanton  No County Name County
# 9506  Medtronic Ablation Frontiers LLC       Carlsbad  No County Name County
#
#       Employees               Layoff/Closure  Year
# 9502       86.0             Layoff Permanent  2015
# 9503       49.0            Closure Permanent  2015
# 9504       11.0            Closure Permanent  2015
# 9505       18.0  Layoff Unknown at this time  2015
# 9506       50.0            Closure Permanent  2015

# %%
cali_layoffs['County'].unique()
# Out:
# array(['Los Angeles County', 'Orange County', 'San Bernardino County',
#        'San Diego County', 'Sacramento County', 'Alameda County',
#        'Santa Clara County', 'San Francisco County', 'Stanislaus County',
#        'Contra Costa County', 'Riverside County', 'Solano County',
#        'Ventura County', 'Monterey County', 'Placer County',
#        'San Mateo County', 'Santa Barbara County', 'Fresno County',
#        'Kings County', 'Kern County', 'Santa Cruz County',
#        'Tehama County', 'Mendocino County', 'San Joaquin County',
#        'Butte County', 'Sonoma County', 'Napa County', 'Calaveras County',
#        'San Luis Obispo County', 'Siskiyou County', 'Yolo County',
#        'Yuba County', 'Sutter County', 'Tulare County',
#        'El Dorado County', 'Marin County', 'Mariposa County',
#        'Imperial County', 'Shasta County', 'Madera County',
#        'Del Norte County', 'Mono County', 'Merced County',
#        'Humboldt County', 'San Benito County', 'Nevada County',
#        'Tuolumne County', 'Amador County', 'Glenn County',
#        'Colusa County', 'Plumas County', 'Inyo County',
#        'No County Name County'], dtype=object)

# %%
years = ['2020', '2019']

# %% [markdown]
# ## Extracting Only Necessary Records
#
# Now that the data has been somewhat standardized, we will be selecting the records that have a notice date from the year 2020 or 2019. This will allow for comparisons between a pandemic and non-pandemic year in terms of layoff notices.

# %%
cali_2020_2019 = cali_layoffs[cali_layoffs["Year"].isin(years)]
cali_2020_2019
# Out:
#      Notice Date Effective Date Received Date  \
# 0     10/26/2020     12/28/2020    11/10/2020
# 1     10/27/2020     12/31/2020    11/10/2020
# 2     10/26/2020     12/16/2020    11/10/2020
# 3     10/01/2020     10/05/2020    11/10/2020
# 4     10/26/2020     07/07/2020    11/10/2020
# ...          ...            ...           ...
# 6740  06/28/2019     08/28/2019    06/28/2019
# 6741  06/28/2019     08/28/2019    06/28/2019
# 6742  06/28/2019     08/28/2019    06/28/2019
# 6743  06/28/2019     08/30/2019    06/28/2019
# 6744  06/28/2019     08/31/2019    06/28/2019
#
#                                    Company              City  \
# 0                       DAMAC Products LLC         La Mirada
# 1                               Gulfstream        Long Beach
# 2          Renaissance Newport Beach Hotel     Newport Beach
# 3                         Howmet Aerospace  Rancho Cucamonga
# 4                Newport Diversified, Inc.          El Cajon
# ...                                    ...               ...
# 6740  California Comfort Systems USA, Inc.   North Highlands
# 6741  California Comfort Systems USA, Inc.           Ontario
# 6742  California Comfort Systems USA, Inc.         San Diego
# 6743                       Coloredge, Inc.           Burbank
# 6744              Verity Business Services          San Jose
#
#                      County  Employees     Layoff/Closure  Year
# 0        Los Angeles County       79.0  Closure Permanent  2020
# 1        Los Angeles County      608.0  Closure Permanent  2020
# 2             Orange County      104.0  Closure Permanent  2020
# 3     San Bernardino County       66.0   Layoff Temporary  2020
# 4          San Diego County       91.0   Layoff Temporary  2020
# ...                     ...        ...                ...   ...
# 6740      Sacramento County       15.0  Closure Permanent  2019
# 6741  San Bernardino County       16.0  Closure Permanent  2019
# 6742       San Diego County       84.0  Closure Permanent  2019
# 6743     Los Angeles County       32.0  Closure Permanent  2019
# 6744     Santa Clara County        5.0   Layoff Permanent  2019
#
# [6369 rows x 9 columns]

# %%
cali_2020_2019['County'].unique()
# Out:
# array(['Los Angeles County', 'Orange County', 'San Bernardino County',
#        'San Diego County', 'Sacramento County', 'Alameda County',
#        'Santa Clara County', 'San Francisco County', 'Stanislaus County',
#        'Contra Costa County', 'Riverside County', 'Solano County',
#        'Ventura County', 'Monterey County', 'Placer County',
#        'San Mateo County', 'Santa Barbara County', 'Fresno County',
#        'Kings County', 'Kern County', 'Santa Cruz County',
#        'Tehama County', 'Mendocino County', 'San Joaquin County',
#        'Butte County', 'Sonoma County', 'Napa County', 'Calaveras County',
#        'San Luis Obispo County', 'Siskiyou County', 'Yolo County',
#        'Yuba County', 'Sutter County', 'Tulare County',
#        'El Dorado County', 'Marin County', 'Mariposa County',
#        'Imperial County', 'Shasta County', 'Madera County',
#        'Del Norte County', 'Mono County', 'Merced County',
#        'Humboldt County', 'San Benito County', 'Nevada County',
#        'Tuolumne County', 'Amador County', 'Glenn County',
#        'Colusa County', 'Plumas County', 'Inyo County'], dtype=object)

# %% [markdown]
# ## More Data Cleaning

# %% [markdown]
# A few records have the incorrect county, based on the information in the city column. These cities include: Sacramento, Hayward, Indian Wells, Cerritos, Vista, Roseville, City of Industry, Del Mar, Walnut Creek, Los Gatos

# %%
dict_cities = {
    'Sacramento':'Sacramento County',
    'San Francisco':'San Francisco County',
    'Hayward':'Alameda County',
    'Indian Wells':'Riverside County',
    'Cerritos':'Los Angeles County',
    'Vista':'San Diego County',
    'Roseville':'Placer County',
    'City of Industry':'Los Angeles County',
    'Del Mar':'San Diego County',
    'Walnut Creek':'Contra Costa County',
    'Los Gatos':'Santa Clara County'
}

# %%
wrong_county = cali_2020_2019[(cali_2020_2019['City'] == 'Sacramento') & (cali_2020_2019['County'] == 'Del Norte County')]
cali_2020_2019.loc[1793,'County'] = 'Sacramento County'
wrong_county = cali_2020_2019[(cali_2020_2019['City'] == 'Hayward') & (cali_2020_2019['County'] == 'Contra Costa County')]
cali_2020_2019.loc[5749,'County'] = 'Alameda County'
wrong_county = cali_2020_2019[(cali_2020_2019['City'] == 'Indian Wells') & (cali_2020_2019['County'] == 'San Benito County')]
cali_2020_2019.loc[5246,'County'] = 'Riverside County'
wrong_county = cali_2020_2019[(cali_2020_2019['City'] == 'Cerritos') & (cali_2020_2019['County'] == 'Orange County')]
cali_2020_2019.loc[3168,'County'] = 'Los Angeles County'
wrong_county = cali_2020_2019[(cali_2020_2019['City'] == 'Vista') & (cali_2020_2019['County'] == 'San Francisco County')]
cali_2020_2019.loc[5202,'County'] = 'San Diego County'
wrong_county = cali_2020_2019[(cali_2020_2019['City'] == 'Roseville') & (cali_2020_2019['County'] == 'Sacramento County')]
cali_2020_2019.loc[4748,'County'] = 'Placer County'
wrong_county = cali_2020_2019[(cali_2020_2019['City'] == 'City of Industry') & (cali_2020_2019['County'] == 'Orange County')]
cali_2020_2019.loc[1772,'County'] = 'Los Angeles County'
wrong_county = cali_2020_2019[(cali_2020_2019['City'] == 'Del Mar') & (cali_2020_2019['County'] == 'Orange County')]
cali_2020_2019.loc[5190,'County'] = 'San Diego County'
wrong_county = cali_2020_2019[(cali_2020_2019['City'] == 'Walnut Creek') & (cali_2020_2019['County'] == 'Alameda County')]
cali_2020_2019.loc[4433,'County'] = 'Contra Costa County'
wrong_county = cali_2020_2019[(cali_2020_2019['City'] == 'Los Gatos') & (cali_2020_2019['County'] == 'Santa Cruz County')]
cali_2020_2019.loc[2648,'County'] = 'Santa Clara County'
# Out:
# /Users/dilcia_mercedes/.local/share/virtualenvs/cali_WARN-MY_IDcvv/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
cali_dict = cali_layoffs.to_dict(orient='records')
cali_dict[9506]
# Out:
# {'Notice Date': '06/30/2015',
#  'Effective Date': '07/22/2015',
#  'Received Date': '06/30/2015',
#  'Company': 'Medtronic Ablation Frontiers LLC',
#  'City': 'Carlsbad',
#  'County': 'No County Name County',
#  'Employees': 50.0,
#  'Layoff/Closure': 'Closure Permanent',
#  'Year': '2015'}

# %%
rows_with_no_county = [r for r in cali_dict if r["County"] == "No County Name County"]
rows_with_no_county[0]
# Out:
# {'Notice Date': '06/30/2016',
#  'Effective Date': '08/31/2016',
#  'Received Date': '07/01/2016',
#  'Company': 'DCS Facility Services',
#  'City': 'Antelope',
#  'County': 'No County Name County',
#  'Employees': 55.0,
#  'Layoff/Closure': 'Closure Permanent',
#  'Year': '2016'}

# %%
len(rows_with_no_county)
# Out:
# 2117

# %%
len(cali_dict)
# Out:
# 9507

# %%
cities = [r["City"] for r in rows_with_no_county]
cities = set(cities)
len(cities)
# Out:
# 355

# %%
rows_with_county = [r for r in cali_dict if r["County"] != "No County Name County"]
rows_with_county[0]
# Out:
# {'Notice Date': '10/26/2020',
#  'Effective Date': '12/28/2020',
#  'Received Date': '11/10/2020',
#  'Company': 'DAMAC Products LLC',
#  'City': 'La Mirada',
#  'County': 'Los Angeles County',
#  'Employees': 79.0,
#  'Layoff/Closure': 'Closure Permanent',
#  'Year': '2020'}

# %%
city_to_counties = {}
for row in rows_with_county:
    city = row["City"]
    county = row["County"]
    if city not in city_to_counties:
        city_to_counties[city] = set()
    city_to_counties[city].add(county)

# %%
# city_to_counties

# %%
unambiguous_cities = [pair for pair in city_to_counties.items() if len(pair[1]) == 1]
unambiguous_cities = {pair[0]: list(pair[1])[0] for pair in city_to_counties.items() if len(pair[1]) == 1}
ambiguous_cities = [pair for pair in city_to_counties.items() if len(pair[1]) > 1]
len(ambiguous_cities)
ambiguous_cities
# Out:
# [('Sacramento', {'Del Norte County', 'Sacramento County'}),
#  ('San Francisco', {'San Francisco County', 'San Mateo County'}),
#  ('Hayward', {'Alameda County', 'Contra Costa County'}),
#  ('Indian Wells', {'Riverside County', 'San Benito County'}),
#  ('Cerritos', {'Los Angeles County', 'Orange County'}),
#  ('Vista', {'San Diego County', 'San Francisco County'}),
#  ('Roseville', {'Placer County', 'Sacramento County'}),
#  ('City of Industry', {'Los Angeles County', 'Orange County'}),
#  ('Del Mar', {'Orange County', 'San Diego County'}),
#  ('Walnut Creek', {'Alameda County', 'Contra Costa County'}),
#  ('Los Gatos', {'Santa Clara County', 'Santa Cruz County'}),
#  ('Rancho', {'Los Angeles County', 'San Bernardino County'})]

# %%
unambiguous_cities
# Out:
# {'La Mirada': 'Los Angeles County',
#  'Long Beach': 'Los Angeles County',
#  'Newport Beach': 'Orange County',
#  'Rancho Cucamonga': 'San Bernardino County',
#  'El Cajon': 'San Diego County',
#  'Universal City': 'Los Angeles County',
#  'San Fernando': 'Los Angeles County',
#  'Beverly Hills': 'Los Angeles County',
#  'Lake Forest': 'Orange County',
#  'Huntington Beach': 'Orange County',
#  'San Diego': 'San Diego County',
#  'Anaheim': 'Orange County',
#  'Union City': 'Alameda County',
#  'Los Angeles': 'Los Angeles County',
#  'Mountain View': 'Santa Clara County',
#  'San Jose': 'Santa Clara County',
#  'Santa Clara': 'Santa Clara County',
#  'Burbank': 'Los Angeles County',
#  'Hollywood': 'Los Angeles County',
#  'Carlsbad': 'San Diego County',
#  'Hawaiian Gardens': 'Los Angeles County',
#  'Whittier': 'Los Angeles County',
#  'Downey': 'Los Angeles County',
#  'La Habra': 'Orange County',
#  'Torrance': 'Los Angeles County',
#  'Paramount': 'Los Angeles County',
#  'Baldwin Park': 'Los Angeles County',
#  'Riverbank': 'Stanislaus County',
#  'Concord': 'Contra Costa County',
#  'Rancho Dominguez': 'Los Angeles County',
#  'Alameda': 'Alameda County',
#  'Culver City': 'Los Angeles County',
#  'Corona': 'Riverside County',
#  'Fairfield': 'Solano County',
#  'Arcadia': 'Los Angeles County',
#  'Ventura': 'Ventura County',
#  'Pacific Grove': 'Monterey County',
#  'Cupertino': 'Santa Clara County',
#  'Sunnyvale': 'Santa Clara County',
#  'Pleasanton': 'Alameda County',
#  'Santa Monica': 'Los Angeles County',
#  'Ontario': 'San Bernardino County',
#  'Palmdale': 'Los Angeles County',
#  'North Hills': 'Los Angeles County',
#  'Mission Hills': 'Los Angeles County',
#  'Stanford': 'Santa Clara County',
#  'Sylmar': 'Los Angeles County',
#  'Pasadena': 'Los Angeles County',
#  'Monterey': 'Monterey County',
#  'Westminster': 'Orange County',
#  'Lincoln': 'Placer County',
#  'Rancho Mirage': 'Riverside County',
#  'Menlo Park': 'San Mateo County',
#  'Santa Maria': 'Santa Barbara County',
#  'Simi Valley': 'Ventura County',
#  'Berkeley': 'Alameda County',
#  'Rocklin': 'Placer County',
#  'Fontana': 'San Bernardino County',
#  'South San Francisco': 'San Mateo County',
#  'Santa Fe Springs': 'Los Angeles County',
#  'Costa Mesa': 'Orange County',
#  'West Hills': 'Los Angeles County',
#  'Oakland': 'Alameda County',
#  'Seal Beach': 'Orange County',
#  'La Jolla': 'San Diego County',
#  'Reedley': 'Fresno County',
#  'Hanford': 'Kings County',
#  'Fresno': 'Fresno County',
#  'Bakersfield': 'Kern County',
#  'Compton': 'Los Angeles County',
#  'Felton': 'Santa Cruz County',
#  'Canoga Park': 'Los Angeles County',
#  'South Gate': 'Los Angeles County',
#  'Playa Vista': 'Los Angeles County',
#  'Azusa': 'Los Angeles County',
#  'Temecula': 'Riverside County',
#  'Camarillo': 'Ventura County',
#  'Red Bluff': 'Tehama County',
#  'El Segundo': 'Los Angeles County',
#  'Willits': 'Mendocino County',
#  'San Bernardino': 'San Bernardino County',
#  'San Mateo': 'San Mateo County',
#  'Modesto': 'Stanislaus County',
#  'Fort Bragg': 'Mendocino County',
#  'West Hollywood': 'Los Angeles County',
#  'Rancho Cordova': 'Sacramento County',
#  'Grand Terrace': 'San Bernardino County',
#  'Stockton': 'San Joaquin County',
#  'Palo Alto': 'Santa Clara County',
#  'Danville': 'Contra Costa County',
#  'North Hollywood': 'Los Angeles County',
#  'Carmel': 'Monterey County',
#  'Garden Grove': 'Orange County',
#  'Orange': 'Orange County',
#  'Chula Vista': 'San Diego County',
#  'Redwood City': 'San Mateo County',
#  'Milpitas': 'Santa Clara County',
#  'Commerce': 'Los Angeles County',
#  'Chatsworth': 'Los Angeles County',
#  'Irvine': 'Orange County',
#  'Rancho Santa Fe': 'San Diego County',
#  'San Clemente': 'Orange County',
#  'San Bruno': 'San Mateo County',
#  'Newark': 'Alameda County',
#  'Santa Ana': 'Orange County',
#  'Burlingame': 'San Mateo County',
#  'Thousand Oaks': 'Ventura County',
#  'Chico': 'Butte County',
#  'Glendale': 'Los Angeles County',
#  'Pittsburg': 'Contra Costa County',
#  'Ceres': 'Stanislaus County',
#  'Monrovia': 'Los Angeles County',
#  'Riverside': 'Riverside County',
#  'Scotts Valley': 'Santa Cruz County',
#  'Santa Rosa': 'Sonoma County',
#  'Patterson': 'Stanislaus County',
#  'Windsor': 'Sonoma County',
#  'Pacific Palisades': 'Los Angeles County',
#  'Laguna Beach': 'Orange County',
#  'Cathedral City': 'Riverside County',
#  'Chino Hills': 'San Bernardino County',
#  'San Marcos': 'San Diego County',
#  'Westlake Village': 'Ventura County',
#  'Cypress': 'Orange County',
#  'Turlock': 'Stanislaus County',
#  'Gardena': 'Los Angeles County',
#  'Dana Point': 'Orange County',
#  'Highland': 'San Bernardino County',
#  'Emeryville': 'Alameda County',
#  'Woodland Hills': 'Los Angeles County',
#  'Napa': 'Napa County',
#  'Santa Cruz': 'Santa Cruz County',
#  'Indio': 'Riverside County',
#  'Half Moon Bay': 'San Mateo County',
#  'Rancho Palos Verdes': 'Los Angeles County',
#  'Soledad': 'Monterey County',
#  'Oakville': 'Napa County',
#  'San Carlos': 'San Mateo County',
#  'Angels Camp': 'Calaveras County',
#  'Pomona': 'Los Angeles County',
#  'Big Bear Lake': 'San Bernardino County',
#  'Oceanside': 'San Diego County',
#  'San Luis Obispo': 'San Luis Obispo County',
#  'Tracy': 'San Joaquin County',
#  'Vacaville': 'Solano County',
#  'Oxnard': 'Ventura County',
#  'Laguna Niguel': 'Orange County',
#  'Folsom': 'Sacramento County',
#  'Brisbane': 'San Mateo County',
#  'Buena Park': 'Orange County',
#  'Mira Loma': 'Riverside County',
#  'Palm Desert': 'Riverside County',
#  'Salinas': 'Monterey County',
#  'Yreka': 'Siskiyou County',
#  'Valencia': 'Los Angeles County',
#  'Claremont': 'Los Angeles County',
#  'Clovis': 'Fresno County',
#  'Coronado': 'San Diego County',
#  'Santa Barbara': 'Santa Barbara County',
#  'Rowland Heights': 'Los Angeles County',
#  'Pebble Beach': 'Monterey County',
#  'Newman': 'Stanislaus County',
#  'Escondido': 'San Diego County',
#  'Marina del Rey': 'Los Angeles County',
#  'Carson': 'Los Angeles County',
#  'Fallbrook': 'San Diego County',
#  'Ukiah': 'Mendocino County',
#  'San Ramon': 'Contra Costa County',
#  'Madison': 'Yolo County',
#  'Beale Afb': 'Yuba County',
#  'Saint Helena': 'Napa County',
#  'Poway': 'San Diego County',
#  'Lodi': 'San Joaquin County',
#  'Yuba City': 'Sutter County',
#  'Tulare': 'Tulare County',
#  'Moreno Valley': 'Riverside County',
#  'Brea': 'Orange County',
#  'Watsonville': 'Santa Cruz County',
#  'Exeter': 'Tulare County',
#  'Davis': 'Yolo County',
#  'San Leandro': 'Alameda County',
#  'West Covina': 'Los Angeles County',
#  'Palm Springs': 'Riverside County',
#  'Gilroy': 'Santa Clara County',
#  'Dublin': 'Alameda County',
#  'El Monte': 'Los Angeles County',
#  'Fountain Valley': 'Orange County',
#  'Sun Valley': 'Los Angeles County',
#  'Capistrano Beach': 'Orange County',
#  'Panorama City': 'Los Angeles County',
#  'Pinole': 'Contra Costa County',
#  'Rohnert Park': 'Sonoma County',
#  'National City': 'San Diego County',
#  'Mc Farland': 'Kern County',
#  'American Canyon': 'Napa County',
#  'Fullerton': 'Orange County',
#  'Studio City': 'Los Angeles County',
#  'Rosemead': 'Los Angeles County',
#  'Fawnskin': 'San Bernardino County',
#  'Inglewood': 'Los Angeles County',
#  'South Lake Tahoe': 'El Dorado County',
#  'West Sacramento': 'Yolo County',
#  'Livermore': 'Alameda County',
#  'Newbury Park': 'Ventura County',
#  'Fremont': 'Alameda County',
#  'Arvin': 'Kern County',
#  'Encino': 'Los Angeles County',
#  'Foothill Ranch': 'Orange County',
#  'Boron': 'Kern County',
#  'Hermosa Beach': 'Los Angeles County',
#  'Harbor City': 'Los Angeles County',
#  'Chino': 'San Bernardino County',
#  'Martinez': 'Contra Costa County',
#  'Rio Linda': 'Sacramento County',
#  'Woodland': 'Yolo County',
#  'Sausalito': 'Marin County',
#  'Yosemite National Park': 'Mariposa County',
#  'Albany': 'Alameda County',
#  'Ballard': 'Santa Barbara County',
#  'San Pedro': 'Los Angeles County',
#  'La Canada Flintridge': 'Los Angeles County',
#  'Sonoma': 'Sonoma County',
#  'El Centro': 'Imperial County',
#  'Spreckels': 'Monterey County',
#  'Redlands': 'San Bernardino County',
#  'Delano': 'Kern County',
#  'Rosamond': 'Kern County',
#  'Montclair': 'San Bernardino County',
#  'Manteca': 'San Joaquin County',
#  'Saratoga': 'Santa Clara County',
#  'Los Altos': 'Santa Clara County',
#  'Maywood': 'Los Angeles County',
#  'Rancho Santa Margarita': 'Orange County',
#  'Encinitas': 'San Diego County',
#  'Redding': 'Shasta County',
#  'Seaside': 'Monterey County',
#  'Madera': 'Madera County',
#  'Daly City': 'San Mateo County',
#  'Visalia': 'Tulare County',
#  'Auburn': 'Placer County',
#  'Colma': 'San Mateo County',
#  'Winters': 'Yolo County',
#  'San Rafael': 'Marin County',
#  'Vernon': 'Los Angeles County',
#  'Healdsburg': 'Sonoma County',
#  'Fort Irwin': 'San Bernardino County',
#  'Sherman Oaks': 'Los Angeles County',
#  'Crescent City': 'Del Norte County',
#  'La Puente': 'Los Angeles County',
#  'Campbell': 'Santa Clara County',
#  'Mammoth Lakes': 'Mono County',
#  'Petaluma': 'Sonoma County',
#  'Agoura Hills': 'Los Angeles County',
#  'Point Mugu Nawc': 'Ventura County',
#  'San Martin': 'Santa Clara County',
#  'Hawthorne': 'Los Angeles County',
#  'Angelus Oaks': 'San Bernardino County',
#  'Citrus Heights': 'Sacramento County',
#  'Irwindale': 'Los Angeles County',
#  'Solana Beach': 'San Diego County',
#  'Lathrop': 'San Joaquin County',
#  'Porterville': 'Tulare County',
#  'Los Alamitos': 'Orange County',
#  'Redondo Beach': 'Los Angeles County',
#  'Rolling Hills Estates': 'Los Angeles County',
#  'Novato': 'Marin County',
#  'Kentfield': 'Marin County',
#  'Running Springs': 'San Bernardino County',
#  'Edwards': 'Kern County',
#  'Lake Arrowhead': 'San Bernardino County',
#  'Artesia': 'Los Angeles County',
#  'Solvang': 'Santa Barbara County',
#  'Tehachapi': 'Kern County',
#  'Corte Madera': 'Marin County',
#  'Elk Grove': 'Sacramento County',
#  'La Verne': 'Los Angeles County',
#  'Lakewood': 'Los Angeles County',
#  'Lancaster': 'Los Angeles County',
#  'San Dimas': 'Los Angeles County',
#  'Van Nuys': 'Los Angeles County',
#  'Manhattan Beach': 'Los Angeles County',
#  'Northridge': 'Los Angeles County',
#  'Barstow': 'San Bernardino County',
#  'Calabasas': 'Los Angeles County',
#  'Paso Robles': 'San Luis Obispo County',
#  'Santa Clarita': 'Los Angeles County',
#  'Pleasant Grove': 'Sutter County',
#  'Borrego Springs': 'San Diego County',
#  'La Mesa': 'San Diego County',
#  'Lompoc': 'Santa Barbara County',
#  'Diamond Bar': 'Los Angeles County',
#  'Murrieta': 'Riverside County',
#  'Marysville': 'Yuba County',
#  'Cardiff By The Sea': 'San Diego County',
#  'Grover Beach': 'San Luis Obispo County',
#  'Port Hueneme': 'Ventura County',
#  'East RanchoDominguez': 'Los Angeles County',
#  'Capitola': 'Santa Cruz County',
#  'Wheatland': 'Yuba County',
#  'San Ysidro': 'San Diego County',
#  'Merced': 'Merced County',
#  'Denair': 'Stanislaus County',
#  'Atwater': 'Merced County',
#  'Carmel By The Sea': 'Monterey County',
#  'Lakeside': 'San Diego County',
#  'Pauma Valley': 'San Diego County',
#  'Santa Clarity': 'Los Angeles County',
#  'Richmond': 'Contra Costa County',
#  'Lynwood': 'Los Angeles County',
#  'Mariposa': 'Mariposa County',
#  'Hacienda Heights': 'Los Angeles County',
#  'El Portal': 'Mariposa County',
#  'Menifee': 'Riverside County',
#  'Lemoore': 'Kings County',
#  'Newhall': 'Los Angeles County',
#  'Aptos': 'Santa Cruz County',
#  'Fish Camp': 'Mariposa County',
#  'Brawley': 'Imperial County',
#  'San Juan Capistrano': 'Orange County',
#  'Shasta Lake': 'Shasta County',
#  'Arcata': 'Humboldt County',
#  'Antioch': 'Contra Costa County',
#  'Adelanto': 'San Bernardino County',
#  'Vallejo': 'Solano County',
#  'Perris': 'Riverside County',
#  'Montebello': 'Los Angeles County',
#  'Larkspur': 'Marin County',
#  'Hemet': 'Riverside County',
#  'Taft': 'Kern County',
#  'TARZANA': 'Los Angeles County',
#  'Diablo': 'Contra Costa County',
#  'Big Bear City': 'San Bernardino County',
#  'Industry': 'Los Angeles County',
#  'Canyon Country': 'Los Angeles County',
#  'Norwalk': 'Los Angeles County',
#  'Winchester': 'Riverside County',
#  'Hollister': 'San Benito County',
#  'Twin Peaks': 'San Bernardino County',
#  'Sebastopol': 'Sonoma County',
#  'Mission Viejo': 'Orange County',
#  'Corona Del Mar': 'Orange County',
#  'Lebec': 'Kern County',
#  'Lake Elsinore': 'Riverside County',
#  'Victorville': 'San Bernardino County',
#  'Goleta': 'Santa Barbara County',
#  'Pico Rivera': 'Los Angeles County',
#  'Truckee': 'Nevada County',
#  'La Quinta': 'Riverside County',
#  'Colton': 'San Bernardino County',
#  'Tustin': 'Orange County',
#  'FULLERTON': 'Orange County',
#  'San Lorenzo': 'Alameda County',
#  'Desert Hot Springs': 'Riverside County',
#  'Signal Hill': 'Los Angeles County',
#  'Malibu': 'Los Angeles County',
#  'Aliso Viejo': 'Orange County',
#  'Newport Coast': 'Orange County',
#  'Dixon': 'Solano County',
#  'Venice': 'Los Angeles County',
#  'San Gabriel': 'Los Angeles County',
#  'Playa Del Rey': 'Los Angeles County',
#  'Mill Valley': 'Marin County',
#  'Coachella': 'Riverside County',
#  'Walnut': 'Los Angeles County',
#  'Oak View': 'Ventura County',
#  'Porter Ranch': 'Los Angeles County',
#  'Wilmington': 'Los Angeles County',
#  'Greenbrae': 'Marin County',
#  'Glen Ellen': 'Sonoma County',
#  'Hercules': 'Contra Costa County',
#  'South Pasadena': 'Los Angeles County',
#  'King City': 'Monterey County',
#  'Buellton': 'Santa Barbara County',
#  'Marina Del Rey': 'Los Angeles County',
#  'Occidental': 'Sonoma County',
#  'Altadena': 'Los Angeles County',
#  'Temple City': 'Los Angeles County',
#  'Bloomington': 'San Bernardino County',
#  'Funner': 'San Diego County',
#  'Morgan Hill': 'Santa Clara County',
#  'Sonora': 'Tuolumne County',
#  'Tarzana': 'Los Angeles County',
#  'Big Sur': 'Monterey County',
#  'Yountville': 'Napa County',
#  'Pleasant Hill': 'Contra Costa County',
#  'Tiburon': 'Marin County',
#  'Sutter Creek': 'Amador County',
#  'Firebaugh': 'Fresno County',
#  'Rancho SantaMargarita': 'Orange County',
#  'El Cerrito': 'Contra Costa County',
#  'Eastvale': 'Riverside County',
#  'El Dorado Hills': 'El Dorado County',
#  'Covina': 'Los Angeles County',
#  'Foster City': 'San Mateo County',
#  'Cabazon': 'Riverside County',
#  'Rialto': 'San Bernardino County',
#  'Upland': 'San Bernardino County',
#  'Strathmore': 'Tulare County',
#  'Cloverdale': 'Sonoma County',
#  'Alhambra': 'Los Angeles County',
#  'Pismo Beach': 'San Luis Obispo County',
#  'Shaver Lake': 'Fresno County',
#  'Tupman': 'Kern County',
#  'Duarte': 'Los Angeles County',
#  'Del Rey Oaks': 'Monterey County',
#  'Apple Valley': 'San Bernardino County',
#  'Millbrae': 'San Mateo County',
#  'Benicia': 'Solano County',
#  'Willows': 'Glenn County',
#  'Yorba Linda': 'Orange County',
#  'Alpine': 'San Diego County',
#  'Belmont': 'San Mateo County',
#  'Reseda': 'Los Angeles County',
#  'Valley Village': 'Los Angeles County',
#  'Olympic Valley': 'Placer County',
#  'San Juan Bautista': 'San Benito County',
#  'Twentynine Palms': 'San Bernardino County',
#  'Hesperia': 'San Bernardino County',
#  'Salida': 'Stanislaus County',
#  'Brentwood': 'Contra Costa County',
#  'Glendora': 'Los Angeles County',
#  'Marina': 'Monterey County',
#  'La Habra Heights': 'Orange County',
#  'Colusa': 'Colusa County',
#  'San Pablo': 'Contra Costa County',
#  'Sunland': 'Los Angeles County',
#  'Jenner': 'Sonoma County',
#  'Cotati': 'Sonoma County',
#  'CITY OF INDUSTRY': 'Los Angeles County',
#  'Selma': 'Fresno County',
#  'Mckinleyville': 'Humboldt County',
#  'Calexico': 'Imperial County',
#  'La Palma': 'Orange County',
#  'Granada Hills': 'Los Angeles County',
#  'Monterey Park': 'Los Angeles County',
#  'Coarsegold': 'Madera County',
#  'Ione': 'Amador County',
#  'Tahoe City': 'Placer County',
#  'La Crescenta': 'Los Angeles County',
#  'Calistoga': 'Napa County',
#  'Norco': 'Riverside County',
#  'VERNON': 'Los Angeles County',
#  'Quincy': 'Plumas County',
#  'Crockett': 'Contra Costa County',
#  'San Jacinto': 'Riverside County',
#  'Orangevale': 'Sacramento County',
#  'Moorpark': 'Ventura County',
#  'Carmel Valley': 'Monterey County',
#  'Ripon': 'San Joaquin County',
#  'Ojai': 'Ventura County',
#  'Death Valley': 'Inyo County',
#  'Bellflower': 'Los Angeles County',
#  'Avalon': 'Los Angeles County',
#  'Atascadero': 'San Luis Obispo County',
#  'Chester': 'Plumas County',
#  'Fillmore': 'Ventura County',
#  'Pacoima': 'Los Angeles County',
#  'Soquel': 'Santa Cruz County',
#  'Bodega Bay': 'Sonoma County',
#  'Loma Linda': 'San Bernardino County',
#  'Huntington Park': 'Los Angeles County',
#  'Shafter': 'Kern County',
#  'Pacheco': 'Contra Costa County',
#  'Rutherford': 'Napa County',
#  'Santee': 'San Diego County',
#  'Laytonville': 'Mendocino County',
#  'Castro Valley': 'Alameda County',
#  'Lafayette': 'Contra Costa County',
#  'Bell Gardens': 'Los Angeles County',
#  'Arroyo Grande': 'San Luis Obispo County',
#  'Tecate': 'San Diego County',
#  'Orland': 'Glenn County',
#  'Oakdale': 'Stanislaus County',
#  'Guadalupe': 'Santa Barbara County',
#  'Mather': 'Sacramento County',
#  'South San': 'San Mateo County',
#  'Santa Fe': 'Los Angeles County',
#  'Huntington': 'Orange County',
#  'Gonzales': 'Monterey County',
#  'Mcclellan': 'Sacramento County',
#  'Rodeo': 'Contra Costa County',
#  'Placerville': 'El Dorado County',
#  'CERRITOS': 'Los Angeles County',
#  'Paradise': 'Butte County',
#  'Banning': 'Riverside County',
#  'West': 'Yolo County',
#  'South El Monte': 'Los Angeles County',
#  'Galt': 'Sacramento County',
#  'South Lake': 'El Dorado County',
#  'Rolling Hills': 'Los Angeles County',
#  'Anderson': 'Shasta County',
#  'Thermal': 'Riverside County',
#  'Kingsburg': 'Fresno County',
#  'Fowler': 'Fresno County',
#  'Yucca Valley': 'San Bernardino County',
#  'Crows Landing': 'Stanislaus County',
#  'San Juan': 'Orange County',
#  'Ridgecrest': 'Kern County',
#  'Arleta': 'Los Angeles County',
#  'Nipomo': 'San Luis Obispo County',
#  'North Highlands': 'Sacramento County',
#  'Manhattan': 'Los Angeles County',
#  'Laguna Hills': 'Orange County',
#  'Eureka': 'Humboldt County',
#  'Lindsay': 'Tulare County',
#  'Livingston': 'Merced County',
#  'Coalinga': 'Fresno County',
#  'Hacienda': 'Los Angeles County',
#  'Carmichael': 'Sacramento County',
#  'Stanton': 'Orange County',
#  'China Lake': 'Kern County',
#  'Montrose': 'Los Angeles County',
#  'Moss Landing': 'Monterey County',
#  'Cudahy': 'Los Angeles County',
#  'Los Banos': 'Merced County',
#  'Alviso': 'Santa Clara County',
#  'Jamul': 'San Diego County',
#  'Gridley': 'Butte County',
#  'Carpinteria': 'Santa Barbara County',
#  'Wallace': 'Calaveras County',
#  'Montecito': 'Santa Barbara County',
#  'American': 'Napa County',
#  'Grass Valley': 'Nevada County',
#  'Moffett Field': 'Santa Clara County'}

# %%
no_county = cali_layoffs[cali_layoffs["County"] == "No County Name County"]
no_county
# Out:
#      Notice Date Effective Date Received Date  \
# 7390  06/30/2016     08/31/2016    07/01/2016
# 7391  06/30/2016     08/31/2016    07/01/2016
# 7392  06/30/2016     08/31/2016    07/01/2016
# 7393  06/30/2016     08/31/2016    07/01/2016
# 7394  06/30/2016     08/31/2016    07/01/2016
# ...          ...            ...           ...
# 9502  06/25/2015     08/24/2015    06/30/2015
# 9503  06/25/2015     08/24/2015    06/30/2015
# 9504  06/25/2015     08/24/2015    06/30/2015
# 9505  06/29/2015     08/28/2015    06/30/2015
# 9506  06/30/2015     07/22/2015    06/30/2015
#
#                                Company           City                 County  \
# 7390             DCS Facility Services       Antelope  No County Name County
# 7391             DCS Facility Services    Bakersfield  No County Name County
# 7392             DCS Facility Services      Brentwood  No County Name County
# 7393             DCS Facility Services          Chico  No County Name County
# 7394             DCS Facility Services         Clovis  No County Name County
# ...                                ...            ...                    ...
# 9502                      Intuit, Inc.  San Francisco  No County Name County
# 9503                      Intuit, Inc.   Santa Monica  No County Name County
# 9504                      Intuit, Inc.         Venice  No County Name County
# 9505                     Safeway, Inc.     Pleasanton  No County Name County
# 9506  Medtronic Ablation Frontiers LLC       Carlsbad  No County Name County
#
#       Employees               Layoff/Closure  Year
# 7390       55.0            Closure Permanent  2016
# 7391       22.0            Closure Permanent  2016
# 7392       22.0            Closure Permanent  2016
# 7393       22.0            Closure Permanent  2016
# 7394       33.0            Closure Permanent  2016
# ...         ...                          ...   ...
# 9502       86.0             Layoff Permanent  2015
# 9503       49.0            Closure Permanent  2015
# 9504       11.0            Closure Permanent  2015
# 9505       18.0  Layoff Unknown at this time  2015
# 9506       50.0            Closure Permanent  2015
#
# [2117 rows x 9 columns]

# %%
no_county["City"].nunique()
# Out:
# 355

# %%
cali_layoffs['County'] = cali_layoffs['City'].map(unambiguous_cities) 
#Leaves nulls for 2020 - shouldn't #doesn't seem to fix 'No County Name' either
# cali_layoffs['County'] = cali_layoffs['City'].replace(unambiguous_cities) #no nulls but county names not clean, don't understand
# cali_layoffs["City"].update(pd.Series(unambiguous_cities)) # didn't do anything

# %%
cali_layoffs.tail()
# Out:
#      Notice Date Effective Date Received Date  \
# 9502  06/25/2015     08/24/2015    06/30/2015
# 9503  06/25/2015     08/24/2015    06/30/2015
# 9504  06/25/2015     08/24/2015    06/30/2015
# 9505  06/29/2015     08/28/2015    06/30/2015
# 9506  06/30/2015     07/22/2015    06/30/2015
#
#                                Company           City              County  \
# 9502                      Intuit, Inc.  San Francisco                 NaN
# 9503                      Intuit, Inc.   Santa Monica  Los Angeles County
# 9504                      Intuit, Inc.         Venice  Los Angeles County
# 9505                     Safeway, Inc.     Pleasanton      Alameda County
# 9506  Medtronic Ablation Frontiers LLC       Carlsbad    San Diego County
#
#       Employees               Layoff/Closure  Year
# 9502       86.0             Layoff Permanent  2015
# 9503       49.0            Closure Permanent  2015
# 9504       11.0            Closure Permanent  2015
# 9505       18.0  Layoff Unknown at this time  2015
# 9506       50.0            Closure Permanent  2015

# %%
cali_layoffs['County'].unique()
# Out:
# array(['Los Angeles County', 'Orange County', 'San Bernardino County',
#        'San Diego County', nan, 'Alameda County', 'Santa Clara County',
#        'Stanislaus County', 'Contra Costa County', 'Riverside County',
#        'Solano County', 'Ventura County', 'Monterey County',
#        'Placer County', 'San Mateo County', 'Santa Barbara County',
#        'Fresno County', 'Kings County', 'Kern County',
#        'Santa Cruz County', 'Tehama County', 'Mendocino County',
#        'Sacramento County', 'San Joaquin County', 'Butte County',
#        'Sonoma County', 'Napa County', 'Calaveras County',
#        'San Luis Obispo County', 'Siskiyou County', 'Yolo County',
#        'Yuba County', 'Sutter County', 'Tulare County',
#        'El Dorado County', 'Marin County', 'Mariposa County',
#        'Imperial County', 'Shasta County', 'Madera County',
#        'Del Norte County', 'Mono County', 'Merced County',
#        'Humboldt County', 'San Benito County', 'Nevada County',
#        'Tuolumne County', 'Amador County', 'Glenn County',
#        'Colusa County', 'Plumas County', 'Inyo County'], dtype=object)

# %%
cali_nulls = cali_layoffs[cali_layoffs['County'].isnull()]
cali_nulls
# Out:
#      Notice Date Effective Date Received Date  \
# 10    10/06/2020     11/05/2020    11/09/2020
# 11    09/30/2020     09/30/2020    11/09/2020
# 20    10/15/2020     12/16/2020    11/06/2020
# 23    07/23/2020     09/22/2020    11/05/2020
# 48    09/17/2020     08/31/2020    10/29/2020
# ...          ...            ...           ...
# 9459  05/27/2015     05/26/2015    06/08/2015
# 9479  06/23/2015     08/23/2015    06/23/2015
# 9488  06/24/2015     08/31/2015    06/29/2015
# 9489  06/25/2015     08/24/2015    06/29/2015
# 9502  06/25/2015     08/24/2015    06/30/2015
#
#                                     Company           City County  Employees  \
# 10                      Natomas Sports Club     Sacramento    NaN       89.0
# 11    WASH Multifamily Laundry Systems, LLC     Sacramento    NaN        1.0
# 20                Hotel Nikko San Francisco  San Francisco    NaN      211.0
# 23         Crescent Hotels and Resorts, LLC     Sacramento    NaN       30.0
# 48                    Alcatraz Cruises, LLC  San Francisco    NaN        2.0
# ...                                     ...            ...    ...        ...
# 9459                            BAE Systems  San Francisco    NaN        1.0
# 9479                              Gap, Inc.  San Francisco    NaN       62.0
# 9488                  University of Phoenix  San Francisco    NaN       14.0
# 9489                           Intuit, Inc.  San Francisco    NaN        6.0
# 9502                           Intuit, Inc.  San Francisco    NaN       86.0
#
#          Layoff/Closure  Year
# 10    Closure Permanent  2020
# 11     Layoff Permanent  2020
# 20     Layoff Permanent  2020
# 23     Layoff Permanent  2020
# 48     Layoff Permanent  2020
# ...                 ...   ...
# 9459   Layoff Temporary  2015
# 9479   Layoff Permanent  2015
# 9488   Layoff Permanent  2015
# 9489   Layoff Permanent  2015
# 9502   Layoff Permanent  2015
#
# [1095 rows x 9 columns]

# %%
# pd.options.display.max_rows = 999
# calicity = cali_layoffs.groupby('City').sum()
# calicity.sort_index(ascending=True)
# calicity.reset_index()

# %%
no_county
# Out:
#      Notice Date Effective Date Received Date  \
# 7390  06/30/2016     08/31/2016    07/01/2016
# 7391  06/30/2016     08/31/2016    07/01/2016
# 7392  06/30/2016     08/31/2016    07/01/2016
# 7393  06/30/2016     08/31/2016    07/01/2016
# 7394  06/30/2016     08/31/2016    07/01/2016
# ...          ...            ...           ...
# 9502  06/25/2015     08/24/2015    06/30/2015
# 9503  06/25/2015     08/24/2015    06/30/2015
# 9504  06/25/2015     08/24/2015    06/30/2015
# 9505  06/29/2015     08/28/2015    06/30/2015
# 9506  06/30/2015     07/22/2015    06/30/2015
#
#                                Company           City                 County  \
# 7390             DCS Facility Services       Antelope  No County Name County
# 7391             DCS Facility Services    Bakersfield  No County Name County
# 7392             DCS Facility Services      Brentwood  No County Name County
# 7393             DCS Facility Services          Chico  No County Name County
# 7394             DCS Facility Services         Clovis  No County Name County
# ...                                ...            ...                    ...
# 9502                      Intuit, Inc.  San Francisco  No County Name County
# 9503                      Intuit, Inc.   Santa Monica  No County Name County
# 9504                      Intuit, Inc.         Venice  No County Name County
# 9505                     Safeway, Inc.     Pleasanton  No County Name County
# 9506  Medtronic Ablation Frontiers LLC       Carlsbad  No County Name County
#
#       Employees               Layoff/Closure  Year
# 7390       55.0            Closure Permanent  2016
# 7391       22.0            Closure Permanent  2016
# 7392       22.0            Closure Permanent  2016
# 7393       22.0            Closure Permanent  2016
# 7394       33.0            Closure Permanent  2016
# ...         ...                          ...   ...
# 9502       86.0             Layoff Permanent  2015
# 9503       49.0            Closure Permanent  2015
# 9504       11.0            Closure Permanent  2015
# 9505       18.0  Layoff Unknown at this time  2015
# 9506       50.0            Closure Permanent  2015
#
# [2117 rows x 9 columns]

# %%
cali_layoffs[cali_layoffs["City"] == 'Rancho']
# Out:
#      Notice Date Effective Date Received Date                      Company  \
# 6054  04/25/2018     06/22/2018    10/01/2018                  Wells Fargo
# 6366  02/01/2019     04/08/2019    02/08/2019      Provident Bank Mortgage
# 6834  08/17/2017     10/17/2017    08/29/2017                   Tamo, Inc.
# 6854  09/11/2017     11/10/2017    09/12/2017  Collection Technology, Inc.
# 6982  11/09/2017     01/02/2018    11/09/2017  Collection Technology, Inc.
# 7130  01/31/2018     04/01/2018    02/02/2018     Compass Group, USA, Inc.
# 7162  11/07/2017     01/07/2018    02/26/2018  Zodiac Seats California LLC
# 7168  03/01/2018     03/15/2018    03/01/2018      Icon Identity Solutions
# 7273  04/25/2018     06/22/2018    05/01/2018                  Wells Fargo
# 7357  06/11/2018     08/11/2018    06/18/2018        Onestop Internet Inc.
# 7666  12/07/2016     02/07/2016    12/12/2016       8009 Day Burgers, Inc.
# 7852  03/25/2017     05/27/2017    03/27/2017            bebe stores, Inc.
# 8002  06/02/2017     08/31/2017    06/02/2017      Mars Food North America
# 8071  06/30/2015     08/31/2015    07/13/2015                First Transit
# 8564  03/18/2016     05/18/2016    03/21/2016  Collection Technology, Inc.
# 8790  07/21/2014     09/22/2014    07/30/2014  Super Glue/Pacer Technology
# 8826  08/05/2014     10/05/2014    08/07/2014           Springleaf Finance
# 8850  08/22/2014     10/22/2014    09/02/2014  Super Glue/Pacer Technology
# 8922  09/29/2014     11/29/2014    10/14/2014  Super Glue/Pacer Technology
# 9136  01/26/2015     03/26/2015    01/29/2015     Sims Recycling Solutions
# 9348  05/01/2015     06/30/2015    05/01/2015      Kumho Tire U.S.A., Inc.
# 9452  06/02/2015     08/03/2015    06/02/2015     Green Tree Servicing LLC
#
#         City County  Employees                Layoff/Closure  Year
# 6054  Rancho    NaN       86.0  Closure Unknown at this time  2018
# 6366  Rancho    NaN        4.0             Closure Permanent  2019
# 6834  Rancho    NaN       38.0             Closure Permanent  2017
# 6854  Rancho    NaN       10.0              Layoff Permanent  2017
# 6982  Rancho    NaN       13.0              Layoff Permanent  2017
# 7130  Rancho    NaN        6.0             Closure Permanent  2018
# 7162  Rancho    NaN      186.0             Closure Permanent  2017
# 7168  Rancho    NaN       22.0             Closure Permanent  2018
# 7273  Rancho    NaN       58.0  Closure Unknown at this time  2018
# 7357  Rancho    NaN       56.0             Closure Permanent  2018
# 7666  Rancho    NaN      136.0             Closure Permanent  2016
# 7852  Rancho    NaN       13.0             Closure Permanent  2017
# 8002  Rancho    NaN       63.0             Closure Permanent  2017
# 8071  Rancho    NaN       71.0              Layoff Permanent  2015
# 8564  Rancho    NaN       51.0              Layoff Permanent  2016
# 8790  Rancho    NaN       14.0              Layoff Permanent  2014
# 8826  Rancho    NaN       10.0             Closure Permanent  2014
# 8850  Rancho    NaN        1.0              Layoff Permanent  2014
# 8922  Rancho    NaN       65.0              Layoff Permanent  2014
# 9136  Rancho    NaN       57.0              Layoff Permanent  2015
# 9348  Rancho    NaN       20.0             Closure Permanent  2015
# 9452  Rancho    NaN       53.0              Layoff Permanent  2015

# %%
## Redo all this analysis with just 2020 + 2019 data. LOL.
