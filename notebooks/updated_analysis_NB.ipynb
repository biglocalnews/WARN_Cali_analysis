# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### The California WARN Analysis
#
# We are comparing 2019 layoffs from the start of the year until 12/11/19, and 2020 layoffs from the start of the year until 12/11/20. This allows us to have a clear picture of the scope of the impact within the same time frame.

# %%
warn_data = pd.read_csv('../data/analysis/finalized_warn_data.csv')

# %%
warn_data.head()
# Out:
#   Notice Date Effective Date Received Date  \
# 0  07/01/2020     09/04/2020    10/02/2020
# 1  07/17/2020     09/23/2020    10/02/2020
# 2  03/25/2020     03/25/2020    03/25/2020
# 3  04/10/2020     03/18/2020    05/01/2020
# 4  03/28/2020     03/17/2020    04/10/2020
#
#                                        Company            City  \
# 0          **CoreLogic Credco, LLC (Cancelled)       San Diego
# 1                      **JC Penney (Cancelled)  San Bernardino
# 2                       1 Hotel West Hollywood  West Hollywood
# 3  1100 Group LLC The Star & Little Star Plaza         Alameda
# 4         115 New Montgomery LLC, DBA The Bird   San Francisco
#
#                   County  Employees     Layoff/Closure            County Orig  \
# 0       San Diego County      137.0   Layoff Permanent       San Diego County
# 1  San Bernardino County      109.0  Closure Permanent  San Bernardino County
# 2     Los Angeles County      223.0   Layoff Temporary     Los Angeles County
# 3         Alameda County       53.0   Layoff Temporary         Alameda County
# 4   San Francisco County       18.0   Layoff Temporary   San Francisco County
#
#      Year Layoff/Closure clean  Population          City 2  \
# 0  2020.0     layoff permanent   3338330.0       san diego
# 1  2020.0    closure permanent   2180085.0  san bernardino
# 2  2020.0     layoff temporary  10039107.0  west hollywood
# 3  2020.0     layoff temporary   1671329.0         alameda
# 4  2020.0     layoff temporary    881549.0   san francisco
#
#     Company_harmonizer_cleaned  Company_harmonizer_score  \
# 0   CORELOGIC CREDCO CANCELLED                  0.000000
# 1          JC PENNEY CANCELLED                 59.462185
# 2       1 HOTEL WEST HOLLYWOOD                 31.301587
# 3  1100 STAR LITTLE STAR PLAZA                 34.318841
# 4      115 NEW MONTGOMERY BIRD                 35.154930
#
#    Company_harmonizer_id              Company_harmonizer_standardized
# 0                    0.0          **CoreLogic Credco, LLC (Cancelled)
# 1                    1.0                      **JC Penney (Cancelled)
# 2                    2.0                       1 Hotel West Hollywood
# 3                    3.0  1100 Group LLC The Star & Little Star Plaza
# 4                    4.0         115 New Montgomery LLC, DBA The Bird

# %%
warn_data.tail()
# Out:
#      Notice Date Effective Date Received Date                    Company  \
# 6365  08/25/2020     10/30/2020    08/27/2020          salesforcecom inc
# 6366  07/28/2020     08/31/2020    07/28/2020                       test
# 6367  04/17/2020     04/20/2020    05/12/2020  thyssenkrupp Aerospace NA
# 6368  05/21/2020     03/31/2020    06/09/2020        travisMatthews, LLC
# 6369  05/21/2020     04/02/2020    06/09/2020        travisMatthews, LLC
#
#                   City                County  Employees    Layoff/Closure  \
# 6365     San Francisco  San Francisco County      165.0  Layoff Permanent
# 6366   West Sacramento           Yolo County       52.0  Layoff Temporary
# 6367  Santa Fe Springs    Los Angeles County       17.0  Layoff Temporary
# 6368  Huntington Beach         Orange County       14.0  Layoff Temporary
# 6369  Huntington Beach         Orange County       24.0  Layoff Permanent
#
#                County Orig    Year Layoff/Closure clean  Population  \
# 6365  San Francisco County  2020.0     layoff permanent    881549.0
# 6366           Yolo County  2020.0     layoff temporary    220500.0
# 6367    Los Angeles County  2020.0     layoff temporary  10039107.0
# 6368         Orange County  2020.0     layoff temporary   3175692.0
# 6369         Orange County  2020.0     layoff permanent   3175692.0
#
#                 City 2 Company_harmonizer_cleaned  Company_harmonizer_score  \
# 6365     san francisco              SALESFORCECOM                 21.590909
# 6366   west sacramento                       TEST                 32.432432
# 6367  santa fe springs  THYSSENKRUPP AEROSPACE NA                 29.577465
# 6368  huntington beach             TRAVISMATTHEWS                 27.418182
# 6369  huntington beach             TRAVISMATTHEWS                100.000000
#
#       Company_harmonizer_id Company_harmonizer_standardized
# 6365                 4697.0               salesforcecom inc
# 6366                 4698.0                            test
# 6367                 4699.0       thyssenkrupp Aerospace NA
# 6368                 4701.0             travisMatthews, LLC
# 6369                 4701.0             travisMatthews, LLC

# %%
## Number of Laid Off Workers 2019

cali_2019_info = warn_data[warn_data['Year'] == 2019]
cali_2019_info['Employees'].sum()
# Out:
# 60719.0

# %%
## Number of Companies that laid people off 2019 

cali_2019_info['Company_harmonizer_cleaned'].nunique()
# Out:
# 480

# %%
## Number of Laid Off Workers 2020

cali_2020_info = warn_data[warn_data['Year'] == 2020]
cali_2020_info['Employees'].sum()
# Out:
# 624963.0

# %%
## Number of Companies that laid people off 2020 

cali_2020_info['Company_harmonizer_cleaned'].nunique()
# Out:
# 4577

# %%
## Number of Laid Off Workers from beginning of 2020 to Dec 11 - which is the most recent data we have.

layoffs_closures_20 = cali_2020_info[cali_2020_info['Notice Date'] < '12/31/2020']
layoffs_closures_20['Employees'].sum()
# Out:
# 624963.0

# %%
## Number of Laid Off Workers from beginning of 2019 to Dec 11 - which is the time frame for the data from 2020.

layoffs_closures_20 = cali_2019_info[cali_2019_info['Notice Date'] < '12/31/2020']
layoffs_closures_20['Employees'].sum()
# Out:
# 60719.0

# %%
## Figures for closures/layoffs in 2019

figures_2019 = cali_2019_info.groupby(['Layoff/Closure']).sum()
figures_2019.reset_index()
figures_2019.drop(columns=['Year','Population'])
# Out:
#                               Employees  Company_harmonizer_score  \
# Layoff/Closure
# Closure Permanent               27928.0              21331.042798
# Closure Temporary                3233.0                613.166410
# Closure Unknown at this time     1233.0                336.402239
# Closure Unknown at thistime       272.0                125.299797
# Layoff Permanent                24185.0              20990.590042
# Layoff Temporary                 1913.0                852.092390
# Layoff Unknown at this time      1361.0               1086.506820
# Layoff Unknown at thistime        594.0                664.228285
#
#                               Company_harmonizer_id
# Layoff/Closure
# Closure Permanent                          867238.0
# Closure Temporary                           22088.0
# Closure Unknown at this time                17767.0
# Closure Unknown at thistime                  4885.0
# Layoff Permanent                           782206.0
# Layoff Temporary                            42047.0
# Layoff Unknown at this time                 44520.0
# Layoff Unknown at thistime                  16551.0

# %%
## Figures for closures/layoffs in 2020

figures_2020 = cali_2020_info.groupby(['Layoff/Closure']).sum()
figures_2020.reset_index()
figures_2020.drop(columns=['Year','Population'])
# Out:
#                              Employees  Company_harmonizer_score  \
# Layoff/Closure
# Closure Permanent              29070.0              17024.540026
# Closure Temporary              72643.0              33839.742463
# Closure Type Unknown             599.0                211.241594
# Closure Unknown at thistime     2804.0               1319.096741
# Layoff Permanent              109623.0              89337.026522
# Layoff Temporary              385091.0             190117.805235
# Layoff Type Unknown             6427.0               3054.915663
# Layoff Unknown at thistime     18706.0               8390.103432
#
#                              Company_harmonizer_id
# Layoff/Closure
# Closure Permanent                         760874.0
# Closure Temporary                        1074628.0
# Closure Type Unknown                        4332.0
# Closure Unknown at thistime                71881.0
# Layoff Permanent                         3214602.0
# Layoff Temporary                         7541472.0
# Layoff Type Unknown                       123443.0
# Layoff Unknown at thistime                364030.0

# %%
layoffs = ['layoff permanent', 'layoff temporary', 'layoff type uncategorized']
closures = ['closure permanent', 'closure temporary', 'closure type uncategorized']

# %%
# of all layoff types (perm, temp, unknown) for 2019

layoffs_2019 = cali_2019_info[cali_2019_info['Layoff/Closure clean'].isin(layoffs)]
layoffs_2019['Employees'].sum()
# Out:
# 28053.0

# %%
# of all closure types (perm, temp, unknown) for 2019

closures_2019 = cali_2019_info[cali_2019_info['Layoff/Closure clean'].isin(closures)]
closures_2019['Employees'].sum()
# Out:
# 32666.0

# %%
# of all layoff types (perm, temp, unknown) for 2020

layoffs_2020 = cali_2020_info[cali_2020_info['Layoff/Closure clean'].isin(layoffs)]
layoffs_2020['Employees'].sum()
# Out:
# 519847.0

# %%
# of all closure types (perm, temp, unknown) for 2020

closures_2020 = cali_2020_info[cali_2020_info['Layoff/Closure clean'].isin(closures)]
closures_2020['Employees'].sum()
# Out:
# 105116.0

# %%
# check that they add up

layoffs_2020['Employees'].sum() + closures_2020['Employees'].sum()
# Out:
# 624963.0

# %%
layoffs_2019['Employees'].sum() + closures_2019['Employees'].sum()
# Out:
# 60719.0

# %%
# Calculations for 2019

employees_sum_2019 = cali_2019_info[['County','Employees']]
layoffs_sum_2019 = employees_sum_2019.groupby('County').agg('sum')
layoffs_sum_2019.reset_index()
# Out:
#                     County  Employees
# 0           Alameda County     3741.0
# 1             Butte County     1874.0
# 2      Contra Costa County     1808.0
# 3            Fresno County     1189.0
# 4             Glenn County      143.0
# 5          Imperial County       44.0
# 6              Kern County     1523.0
# 7       Los Angeles County    14307.0
# 8         Mendocino County       80.0
# 9              Napa County       38.0
# 10           Nevada County      244.0
# 11           Orange County     3831.0
# 12           Placer County      756.0
# 13        Riverside County     3439.0
# 14       Sacramento County     1127.0
# 15   San Bernardino County     3006.0
# 16        San Diego County     3834.0
# 17    San Francisco County     4666.0
# 18      San Joaquin County     1150.0
# 19  San Luis Obispo County      106.0
# 20        San Mateo County     1595.0
# 21    Santa Barbara County      327.0
# 22      Santa Clara County     7365.0
# 23       Santa Cruz County      230.0
# 24           Shasta County      135.0
# 25           Solano County      694.0
# 26           Sonoma County      230.0
# 27       Stanislaus County      774.0
# 28           Tehama County       10.0
# 29           Tulare County      375.0
# 30         Tuolumne County        1.0
# 31          Ventura County     1546.0
# 32             Yolo County      443.0
# 33             Yuba County       88.0

# %%
cali_info_and_sums_19 = pd.merge(cali_2019_info, layoffs_sum_2019, how="left", left_on="County", right_on="County")
cali_info_and_sums_19.rename(columns={'Employees_y':'Total Emp. Laid Off in County', 'Employees_x':'Employees'}, inplace=True)
cali_info_and_sums_19.head()
# Out:
#   Notice Date Effective Date Received Date  \
# 0  08/29/2019     10/29/2019    09/09/2019
# 1  11/15/2019     01/03/2020    11/20/2019
# 2  07/29/2019     09/30/2019    08/19/2019
# 3  04/08/2019     06/15/2019    04/15/2019
# 4  04/08/2019     06/15/2019    04/15/2019
#
#                                            Company           City  \
# 0  360 Support Services, Inc. dba 360 ServiceGroup  Panorama City
# 1                            ACT Fulfillment, Inc.      Mira Loma
# 2                              AECOM (CANCELLED)**      San Diego
# 3                    AG Facilities Operations, LLC     Seal Beach
# 4                    AG Facilities Operations, LLC        La Mesa
#
#                County  Employees    Layoff/Closure         County Orig  \
# 0  Los Angeles County       17.0  Layoff Permanent  Los Angeles County
# 1    Riverside County       45.0  Layoff Permanent    Riverside County
# 2    San Diego County        3.0  Layoff Permanent    San Diego County
# 3       Orange County       76.0  Layoff Permanent       Orange County
# 4    San Diego County       38.0  Layoff Permanent    San Diego County
#
#      Year Layoff/Closure clean  Population         City 2  \
# 0  2019.0     layoff permanent  10039107.0  panorama city
# 1  2019.0     layoff permanent   2470546.0      mira loma
# 2  2019.0     layoff permanent   3338330.0      san diego
# 3  2019.0     layoff permanent   3175692.0     seal beach
# 4  2019.0     layoff permanent   3338330.0        la mesa
#
#               Company_harmonizer_cleaned  Company_harmonizer_score  \
# 0  360 SUPPORT SERVICES 360 SERVICEGROUP                 41.976190
# 1                        ACT FULFILLMENT                 28.137931
# 2                        AECOM CANCELLED                 27.310345
# 3               AG FACILITIES OPERATIONS                 25.963636
# 4               AG FACILITIES OPERATIONS                100.000000
#
#    Company_harmonizer_id                  Company_harmonizer_standardized  \
# 0                   20.0  360 Support Services, Inc. dba 360 ServiceGroup
# 1                   58.0                            ACT Fulfillment, Inc.
# 2                   67.0                              AECOM (CANCELLED)**
# 3                   74.0                    AG Facilities Operations, LLC
# 4                   74.0                    AG Facilities Operations, LLC
#
#    Total Emp. Laid Off in County
# 0                        14307.0
# 1                         3439.0
# 2                         3834.0
# 3                         3831.0
# 4                         3834.0

# %%
cali_info_and_sums_19['Per Capita Laid Off 2019'] = (cali_info_and_sums_19['Total Emp. Laid Off in County']/cali_info_and_sums_19['Population']) * 100000
per_capita_laid_off = cali_info_and_sums_19[['County', 'Per Capita Laid Off 2019']]
per_capita_laid_off.groupby("County").max().sort_values(by='Per Capita Laid Off 2019', ascending=False)
# Out:
#                         Per Capita Laid Off 2019
# County
# Butte County                          854.981614
# San Francisco County                  529.295592
# Glenn County                          503.645265
# Santa Clara County                    382.031401
# Nevada County                         244.599268
# Alameda County                        223.833847
# San Mateo County                      208.068899
# Yolo County                           200.907029
# Placer County                         189.792860
# Ventura County                        182.741021
# Kern County                           169.184250
# Contra Costa County                   156.736823
# Solano County                         155.034257
# San Joaquin County                    150.889329
# Los Angeles County                    142.512676
# Stanislaus County                     140.558602
# Riverside County                      139.199999
# San Bernardino County                 137.884532
# Orange County                         120.635125
# Fresno County                         119.006987
# San Diego County                      114.847843
# Yuba County                           111.862511
# Mendocino County                       92.220083
# Santa Cruz County                      84.183403
# Tulare County                          80.438443
# Shasta County                          74.966681
# Santa Barbara County                   73.236446
# Sacramento County                      72.613266
# Sonoma County                          46.527059
# San Luis Obispo County                 37.441145
# Napa County                            27.587409
# Imperial County                        24.280551
# Tehama County                          15.364759
# Tuolumne County                         1.835603

# %%
# Calculations for 2020

employees_sum_2020 = cali_2020_info[['County','Employees']]
layoffs_sum_2020 = employees_sum_2020.groupby('County').agg('sum')
layoffs_sum_2020.reset_index()
# Out:
#                     County  Employees
# 0           Alameda County    32838.0
# 1            Amador County      159.0
# 2             Butte County     1631.0
# 3         Calaveras County       40.0
# 4            Colusa County       30.0
# 5      Contra Costa County     8168.0
# 6         Del Norte County        6.0
# 7         El Dorado County      819.0
# 8            Fresno County     5809.0
# 9             Glenn County       47.0
# 10         Humboldt County      227.0
# 11         Imperial County      378.0
# 12             Inyo County      670.0
# 13             Kern County     5137.0
# 14            Kings County     1112.0
# 15      Los Angeles County   193233.0
# 16           Madera County     1113.0
# 17            Marin County     2392.0
# 18         Mariposa County     2262.0
# 19        Mendocino County      388.0
# 20           Merced County      339.0
# 21             Mono County      879.0
# 22         Monterey County     8614.0
# 23             Napa County     2843.0
# 24           Nevada County      396.0
# 25           Orange County    63747.0
# 26           Placer County     3230.0
# 27           Plumas County       67.0
# 28        Riverside County    22535.0
# 29       Sacramento County    14718.0
# 30       San Benito County      134.0
# 31   San Bernardino County    19249.0
# 32        San Diego County    79049.0
# 33    San Francisco County    55367.0
# 34      San Joaquin County     4688.0
# 35  San Luis Obispo County     4495.0
# 36        San Mateo County    16819.0
# 37    Santa Barbara County     4802.0
# 38      Santa Clara County    36397.0
# 39       Santa Cruz County     4535.0
# 40           Shasta County      642.0
# 41         Siskiyou County       45.0
# 42           Solano County     2301.0
# 43           Sonoma County     5124.0
# 44       Stanislaus County     2659.0
# 45           Sutter County      380.0
# 46           Tehama County        1.0
# 47           Tulare County     1333.0
# 48         Tuolumne County       70.0
# 49          Ventura County    11577.0
# 50             Yolo County     1310.0
# 51             Yuba County      159.0

# %%
cali_info_and_sums_20 = pd.merge(cali_2020_info, layoffs_sum_2020, how="left", left_on="County", right_on="County")
cali_info_and_sums_20.rename(columns={'Employees_y':'Total Emp. Laid Off in County', 'Employees_x':'Employees'}, inplace=True)
cali_info_and_sums_20.head()
# Out:
#   Notice Date Effective Date Received Date  \
# 0  07/01/2020     09/04/2020    10/02/2020
# 1  07/17/2020     09/23/2020    10/02/2020
# 2  03/25/2020     03/25/2020    03/25/2020
# 3  04/10/2020     03/18/2020    05/01/2020
# 4  03/28/2020     03/17/2020    04/10/2020
#
#                                        Company            City  \
# 0          **CoreLogic Credco, LLC (Cancelled)       San Diego
# 1                      **JC Penney (Cancelled)  San Bernardino
# 2                       1 Hotel West Hollywood  West Hollywood
# 3  1100 Group LLC The Star & Little Star Plaza         Alameda
# 4         115 New Montgomery LLC, DBA The Bird   San Francisco
#
#                   County  Employees     Layoff/Closure            County Orig  \
# 0       San Diego County      137.0   Layoff Permanent       San Diego County
# 1  San Bernardino County      109.0  Closure Permanent  San Bernardino County
# 2     Los Angeles County      223.0   Layoff Temporary     Los Angeles County
# 3         Alameda County       53.0   Layoff Temporary         Alameda County
# 4   San Francisco County       18.0   Layoff Temporary   San Francisco County
#
#      Year Layoff/Closure clean  Population          City 2  \
# 0  2020.0     layoff permanent   3338330.0       san diego
# 1  2020.0    closure permanent   2180085.0  san bernardino
# 2  2020.0     layoff temporary  10039107.0  west hollywood
# 3  2020.0     layoff temporary   1671329.0         alameda
# 4  2020.0     layoff temporary    881549.0   san francisco
#
#     Company_harmonizer_cleaned  Company_harmonizer_score  \
# 0   CORELOGIC CREDCO CANCELLED                  0.000000
# 1          JC PENNEY CANCELLED                 59.462185
# 2       1 HOTEL WEST HOLLYWOOD                 31.301587
# 3  1100 STAR LITTLE STAR PLAZA                 34.318841
# 4      115 NEW MONTGOMERY BIRD                 35.154930
#
#    Company_harmonizer_id              Company_harmonizer_standardized  \
# 0                    0.0          **CoreLogic Credco, LLC (Cancelled)
# 1                    1.0                      **JC Penney (Cancelled)
# 2                    2.0                       1 Hotel West Hollywood
# 3                    3.0  1100 Group LLC The Star & Little Star Plaza
# 4                    4.0         115 New Montgomery LLC, DBA The Bird
#
#    Total Emp. Laid Off in County
# 0                        79049.0
# 1                        19249.0
# 2                       193233.0
# 3                        32838.0
# 4                        55367.0

# %%
cali_info_and_sums_20['Per Capita Laid Off 2020'] = (cali_info_and_sums_20['Total Emp. Laid Off in County']/cali_info_and_sums_20['Population']) * 100000
per_capita_laid_off_20 = cali_info_and_sums_20[['County', 'Per Capita Laid Off 2020']]
per_capita_laid_off_20.groupby("County").max().sort_values(by='Per Capita Laid Off 2020', ascending=False)
# Out:
#                         Per Capita Laid Off 2020
# County
# Mariposa County                     13148.869383
# San Francisco County                 6280.649175
# Mono County                          6085.571864
# Inyo County                          3714.174843
# San Diego County                     2367.920487
# San Mateo County                     2194.050664
# Napa County                          2063.973748
# Orange County                        2007.342022
# Monterey County                      1984.513697
# Alameda County                       1964.783714
# Los Angeles County                   1924.802674
# Santa Clara County                   1887.956129
# Santa Cruz County                    1659.877092
# San Luis Obispo County               1587.716479
# Ventura County                       1368.430011
# Santa Barbara County                 1075.478333
# Sonoma County                        1036.541947
# Sacramento County                     948.289304
# Marin County                          924.172997
# Riverside County                      912.146546
# San Bernardino County                 882.947225
# Placer County                         810.887482
# Butte County                          744.116869
# Kings County                          727.082516
# Contra Costa County                   708.089805
# Madera County                         707.443732
# San Joaquin County                    615.103628
# Yolo County                           594.104308
# Fresno County                         581.422699
# Kern County                           570.649699
# Solano County                         514.025686
# Stanislaus County                     482.875095
# Mendocino County                      447.267404
# El Dorado County                      424.697811
# Amador County                         399.979875
# Nevada County                         396.972583
# Sutter County                         391.869734
# Shasta County                         356.508219
# Plumas County                         356.250332
# Tulare County                         285.931853
# San Benito County                     213.348618
# Imperial County                       208.592004
# Yuba County                           202.115218
# Humboldt County                       167.455997
# Glenn County                          165.533758
# Colusa County                         139.230519
# Tuolumne County                       128.492235
# Merced County                         122.082973
# Siskiyou County                       103.355612
# Calaveras County                       87.136478
# Del Norte County                       21.573422
# Tehama County                           1.536476

# %%
per_capitas = pd.merge(per_capita_laid_off_20, per_capita_laid_off, how='left', left_on="County", right_on="County")
per_capitas.groupby("County").max().sort_values(by='Per Capita Laid Off 2020', ascending=False)
# Out:
#                         Per Capita Laid Off 2020  Per Capita Laid Off 2019
# County
# Mariposa County                     13148.869383                       NaN
# San Francisco County                 6280.649175                529.295592
# Mono County                          6085.571864                       NaN
# Inyo County                          3714.174843                       NaN
# San Diego County                     2367.920487                114.847843
# San Mateo County                     2194.050664                208.068899
# Napa County                          2063.973748                 27.587409
# Orange County                        2007.342022                120.635125
# Monterey County                      1984.513697                       NaN
# Alameda County                       1964.783714                223.833847
# Los Angeles County                   1924.802674                142.512676
# Santa Clara County                   1887.956129                382.031401
# Santa Cruz County                    1659.877092                 84.183403
# San Luis Obispo County               1587.716479                 37.441145
# Ventura County                       1368.430011                182.741021
# Santa Barbara County                 1075.478333                 73.236446
# Sonoma County                        1036.541947                 46.527059
# Sacramento County                     948.289304                 72.613266
# Marin County                          924.172997                       NaN
# Riverside County                      912.146546                139.199999
# San Bernardino County                 882.947225                137.884532
# Placer County                         810.887482                189.792860
# Butte County                          744.116869                854.981614
# Kings County                          727.082516                       NaN
# Contra Costa County                   708.089805                156.736823
# Madera County                         707.443732                       NaN
# San Joaquin County                    615.103628                150.889329
# Yolo County                           594.104308                200.907029
# Fresno County                         581.422699                119.006987
# Kern County                           570.649699                169.184250
# Solano County                         514.025686                155.034257
# Stanislaus County                     482.875095                140.558602
# Mendocino County                      447.267404                 92.220083
# El Dorado County                      424.697811                       NaN
# Amador County                         399.979875                       NaN
# Nevada County                         396.972583                244.599268
# Sutter County                         391.869734                       NaN
# Shasta County                         356.508219                 74.966681
# Plumas County                         356.250332                       NaN
# Tulare County                         285.931853                 80.438443
# San Benito County                     213.348618                       NaN
# Imperial County                       208.592004                 24.280551
# Yuba County                           202.115218                111.862511
# Humboldt County                       167.455997                       NaN
# Glenn County                          165.533758                503.645265
# Colusa County                         139.230519                       NaN
# Tuolumne County                       128.492235                  1.835603
# Merced County                         122.082973                       NaN
# Siskiyou County                       103.355612                       NaN
# Calaveras County                       87.136478                       NaN
# Del Norte County                       21.573422                       NaN
# Tehama County                           1.536476                 15.364759

# %%
layoff_closure_list_perm = ['layoff permanent', 'closure permanent']
layoff_closure_list_temp = ['layoff temporary', 'closure temporary']
counties_list = ['Butte County', 'Santa Cruz County', 'Yolo County', 'Orange County', 'Los Angeles County', 'Humboldt County', 'Fresno County', 'Mariposa County']

# %%
high_rent_burden_20_prm = cali_2020_info[cali_2020_info['County'].isin(counties_list)]
high_rent_burden_20_prm = high_rent_burden_20_prm[high_rent_burden_20_prm['Layoff/Closure clean'].isin(layoff_closure_list_perm)]
high_rent_burden_20_prm = high_rent_burden_20_prm[['County','Layoff/Closure','Employees']]
high_rent_burden_20_prm = high_rent_burden_20_prm.groupby(['County','Layoff/Closure']).sum()
high_rent_burden_20_prm.reset_index('Layoff/Closure')
# Out:
#                        Layoff/Closure  Employees
# County
# Butte County        Closure Permanent       14.0
# Butte County         Layoff Permanent      570.0
# Fresno County       Closure Permanent      980.0
# Fresno County        Layoff Permanent      471.0
# Los Angeles County  Closure Permanent    10976.0
# Los Angeles County   Layoff Permanent    30691.0
# Mariposa County      Layoff Permanent       45.0
# Orange County       Closure Permanent     2037.0
# Orange County        Layoff Permanent    11239.0
# Santa Cruz County   Closure Permanent      447.0
# Santa Cruz County    Layoff Permanent      988.0
# Yolo County         Closure Permanent       84.0
# Yolo County          Layoff Permanent      457.0

# %%
high_rent_burden_19_prm = cali_2019_info[cali_2019_info['County'].isin(counties_list)]
high_rent_burden_19_prm = high_rent_burden_19_prm[high_rent_burden_19_prm['Layoff/Closure clean'].isin(layoff_closure_list_perm)]
high_rent_burden_19_prm = high_rent_burden_19_prm[['County','Layoff/Closure','Employees']]
high_rent_burden_19_prm = high_rent_burden_19_prm.groupby(['County','Layoff/Closure']).sum()
high_rent_burden_19_prm.reset_index('Layoff/Closure')
# Out:
#                        Layoff/Closure  Employees
# County
# Butte County        Closure Permanent      501.0
# Butte County         Layoff Permanent       42.0
# Fresno County       Closure Permanent     1160.0
# Fresno County        Layoff Permanent       10.0
# Los Angeles County  Closure Permanent     7382.0
# Los Angeles County   Layoff Permanent     5795.0
# Orange County       Closure Permanent     2078.0
# Orange County        Layoff Permanent     1501.0
# Santa Cruz County   Closure Permanent      137.0
# Yolo County         Closure Permanent      443.0

# %%
perm_job_loss = pd.merge(high_rent_burden_20_prm, high_rent_burden_19_prm, how='left', left_on=["County", "Layoff/Closure"], right_on=["County", "Layoff/Closure"])
perm_job_loss.rename(columns={'Employees_x':'Employees Laid Off 2020', 'Employees_y':'Employees Laid Off 2019'}, inplace=True)

# %%
high_rent_burden_20_tmp = cali_2020_info[cali_2020_info['County'].isin(counties_list)]
high_rent_burden_20_tmp = high_rent_burden_20_tmp[high_rent_burden_20_tmp['Layoff/Closure clean'].isin(layoff_closure_list_temp)]
high_rent_burden_20_tmp = high_rent_burden_20_tmp[['County','Layoff/Closure','Employees']]
high_rent_burden_20_tmp = high_rent_burden_20_tmp.groupby(['County','Layoff/Closure']).sum()
high_rent_burden_20_tmp.reset_index('Layoff/Closure')
# Out:
#                        Layoff/Closure  Employees
# County
# Butte County         Layoff Temporary     1002.0
# Fresno County       Closure Temporary      882.0
# Fresno County        Layoff Temporary     3476.0
# Humboldt County      Layoff Temporary      227.0
# Los Angeles County  Closure Temporary    19318.0
# Los Angeles County   Layoff Temporary   122790.0
# Mariposa County     Closure Temporary      343.0
# Mariposa County      Layoff Temporary     1874.0
# Orange County       Closure Temporary     7526.0
# Orange County        Layoff Temporary    40809.0
# Santa Cruz County   Closure Temporary      253.0
# Santa Cruz County    Layoff Temporary     2702.0
# Yolo County         Closure Temporary       24.0
# Yolo County          Layoff Temporary      599.0

# %%
high_rent_burden_19_tmp = cali_2019_info[cali_2019_info['County'].isin(counties_list)]
high_rent_burden_19_tmp = high_rent_burden_19_tmp[high_rent_burden_19_tmp['Layoff/Closure clean'].isin(layoff_closure_list_temp)]
high_rent_burden_19_tmp = high_rent_burden_19_tmp[['County','Layoff/Closure','Employees']]
high_rent_burden_19_tmp = high_rent_burden_19_tmp.groupby(['County','Layoff/Closure']).sum()
high_rent_burden_19_tmp.reset_index('Layoff/Closure')
# Out:
#                        Layoff/Closure  Employees
# County
# Butte County        Closure Temporary     1331.0
# Los Angeles County  Closure Temporary      326.0
# Los Angeles County   Layoff Temporary      338.0
# Santa Cruz County    Layoff Temporary       93.0

# %%
temp_job_loss = pd.merge(high_rent_burden_20_tmp, high_rent_burden_19_tmp, how='left', left_on=["County", "Layoff/Closure"], right_on=["County", "Layoff/Closure"])
temp_job_loss.rename(columns={'Employees_x':'Employees Laid Off 2020', 'Employees_y':'Employees Laid Off 2019'}, inplace=True)

# %%
temp_job_loss
# Out:
#                                       Employees Laid Off 2020  \
# County             Layoff/Closure
# Butte County       Layoff Temporary                    1002.0
# Fresno County      Closure Temporary                    882.0
#                    Layoff Temporary                    3476.0
# Humboldt County    Layoff Temporary                     227.0
# Los Angeles County Closure Temporary                  19318.0
#                    Layoff Temporary                  122790.0
# Mariposa County    Closure Temporary                    343.0
#                    Layoff Temporary                    1874.0
# Orange County      Closure Temporary                   7526.0
#                    Layoff Temporary                   40809.0
# Santa Cruz County  Closure Temporary                    253.0
#                    Layoff Temporary                    2702.0
# Yolo County        Closure Temporary                     24.0
#                    Layoff Temporary                     599.0
#
#                                       Employees Laid Off 2019
# County             Layoff/Closure
# Butte County       Layoff Temporary                       NaN
# Fresno County      Closure Temporary                      NaN
#                    Layoff Temporary                       NaN
# Humboldt County    Layoff Temporary                       NaN
# Los Angeles County Closure Temporary                    326.0
#                    Layoff Temporary                     338.0
# Mariposa County    Closure Temporary                      NaN
#                    Layoff Temporary                       NaN
# Orange County      Closure Temporary                      NaN
#                    Layoff Temporary                       NaN
# Santa Cruz County  Closure Temporary                      NaN
#                    Layoff Temporary                      93.0
# Yolo County        Closure Temporary                      NaN
#                    Layoff Temporary                       NaN

# %%
perm_job_loss
# Out:
#                                       Employees Laid Off 2020  \
# County             Layoff/Closure
# Butte County       Closure Permanent                     14.0
#                    Layoff Permanent                     570.0
# Fresno County      Closure Permanent                    980.0
#                    Layoff Permanent                     471.0
# Los Angeles County Closure Permanent                  10976.0
#                    Layoff Permanent                   30691.0
# Mariposa County    Layoff Permanent                      45.0
# Orange County      Closure Permanent                   2037.0
#                    Layoff Permanent                   11239.0
# Santa Cruz County  Closure Permanent                    447.0
#                    Layoff Permanent                     988.0
# Yolo County        Closure Permanent                     84.0
#                    Layoff Permanent                     457.0
#
#                                       Employees Laid Off 2019
# County             Layoff/Closure
# Butte County       Closure Permanent                    501.0
#                    Layoff Permanent                      42.0
# Fresno County      Closure Permanent                   1160.0
#                    Layoff Permanent                      10.0
# Los Angeles County Closure Permanent                   7382.0
#                    Layoff Permanent                    5795.0
# Mariposa County    Layoff Permanent                       NaN
# Orange County      Closure Permanent                   2078.0
#                    Layoff Permanent                    1501.0
# Santa Cruz County  Closure Permanent                    137.0
#                    Layoff Permanent                       NaN
# Yolo County        Closure Permanent                    443.0
#                    Layoff Permanent                       NaN

# %%
high_rent_burden_19_prm = cali_2019_info[cali_2019_info['County'].isin(counties_list)]
high_rent_burden_19_prm = high_rent_burden_19_prm[high_rent_burden_19_prm['Layoff/Closure clean'].isin(layoff_closure_list_perm)]
perm_job_loss_total = high_rent_burden_19_prm[['County','Layoff/Closure','Employees']]
perm_job_loss_total = perm_job_loss_total.groupby(['County']).sum()
perm_job_loss_total
# Out:
#                     Employees
# County
# Butte County            543.0
# Fresno County          1170.0
# Los Angeles County    13177.0
# Orange County          3579.0
# Santa Cruz County       137.0
# Yolo County             443.0

# %%
high_rent_burden_20_prm = cali_2020_info[cali_2020_info['County'].isin(counties_list)]
high_rent_burden_20_prm = high_rent_burden_20_prm[high_rent_burden_20_prm['Layoff/Closure clean'].isin(layoff_closure_list_perm)]
perm_job_loss_total_20 = high_rent_burden_20_prm[['County','Layoff/Closure','Employees']]
perm_job_loss_total_20 = perm_job_loss_total_20.groupby(['County']).sum()
perm_job_loss_total_20
# Out:
#                     Employees
# County
# Butte County            584.0
# Fresno County          1451.0
# Los Angeles County    41667.0
# Mariposa County          45.0
# Orange County         13276.0
# Santa Cruz County      1435.0
# Yolo County             541.0

# %%
sums_2020_2019 = perm_job_loss_total_20.merge(perm_job_loss_total, how="left", left_on="County", right_on="County")
sums_2020_2019.rename(columns={'Employees_x':'Permanent L/C Total 2020','Employees_y':'Permanent L/C Total 2019'}, inplace=True)
sums_2020_2019
# Out:
#                     Permanent L/C Total 2020  Permanent L/C Total 2019
# County
# Butte County                           584.0                     543.0
# Fresno County                         1451.0                    1170.0
# Los Angeles County                   41667.0                   13177.0
# Mariposa County                         45.0                       NaN
# Orange County                        13276.0                    3579.0
# Santa Cruz County                     1435.0                     137.0
# Yolo County                            541.0                     443.0

# %%
high_rent_burden_19_tmp = cali_2019_info[cali_2019_info['County'].isin(counties_list)]
high_rent_burden_19_tmp = high_rent_burden_19_tmp[high_rent_burden_19_tmp['Layoff/Closure clean'].isin(layoff_closure_list_temp)]
temp_job_loss_total = high_rent_burden_19_tmp[['County','Layoff/Closure','Employees']]
temp_job_loss_total = temp_job_loss_total.groupby(['County']).sum()
temp_job_loss_total
# Out:
#                     Employees
# County
# Butte County           1331.0
# Los Angeles County      664.0
# Santa Cruz County        93.0

# %%
high_rent_burden_20_tmp = cali_2020_info[cali_2020_info['County'].isin(counties_list)]
high_rent_burden_20_tmp = high_rent_burden_20_tmp[high_rent_burden_20_tmp['Layoff/Closure clean'].isin(layoff_closure_list_temp)]
temp_job_loss_total_20 = high_rent_burden_20_tmp[['County','Layoff/Closure','Employees']]
temp_job_loss_total_20 = temp_job_loss_total_20.groupby(['County']).sum()
temp_job_loss_total_20
# Out:
#                     Employees
# County
# Butte County           1002.0
# Fresno County          4358.0
# Humboldt County         227.0
# Los Angeles County   142108.0
# Mariposa County        2217.0
# Orange County         48335.0
# Santa Cruz County      2955.0
# Yolo County             623.0

# %%
sums_tmp_2020_2019 = temp_job_loss_total_20.merge(temp_job_loss_total, how="left", left_on="County", right_on="County")
sums_tmp_2020_2019.rename(columns={'Employees_x':'Temporary L/C Total 2020','Employees_y':'Temporary L/C Total 2019'}, inplace=True)
sums_tmp_2020_2019
# Out:
#                     Temporary L/C Total 2020  Temporary L/C Total 2019
# County
# Butte County                          1002.0                    1331.0
# Fresno County                         4358.0                       NaN
# Humboldt County                        227.0                       NaN
# Los Angeles County                  142108.0                     664.0
# Mariposa County                       2217.0                       NaN
# Orange County                        48335.0                       NaN
# Santa Cruz County                     2955.0                      93.0
# Yolo County                            623.0                       NaN

# %%
#Fact Check for # of Layoffs in Mariposa County

Mariposa = cali_2020_info[cali_2020_info['County'] == 'Mariposa County']
Mariposa.groupby('County').sum() # Laid Off Employees totals 2,262
# Out:
#                  Employees     Year  Population  Company_harmonizer_score  \
# County
# Mariposa County     2262.0  12120.0    103218.0                305.125772
#
#                  Company_harmonizer_id
# County
# Mariposa County                 8670.0

# %%
Mariposa.groupby('County').max() # Population totals 17,203
# Out:
#                 Notice Date Effective Date Received Date  \
# County
# Mariposa County  07/30/2020     08/15/2020    08/03/2020
#
#                                   Company                    City  Employees  \
# County
# Mariposa County  NatureBridge at Yosemite  Yosemite National Park     1829.0
#
#                    Layoff/Closure      County Orig    Year  \
# County
# Mariposa County  Layoff Temporary  Mariposa County  2020.0
#
#                 Layoff/Closure clean  Population                  City 2  \
# County
# Mariposa County     layoff temporary     17203.0  yosemite national park
#
#                    Company_harmonizer_cleaned  Company_harmonizer_score  \
# County
# Mariposa County  PORTAL DINING PARKSIDE PIZZA                      63.0
#
#                  Company_harmonizer_id Company_harmonizer_standardized
# County
# Mariposa County                 2913.0        NatureBridge at Yosemite

# %%
Mariposa = cali_2020_info[cali_2020_info['County'] == 'Mariposa County']
Mariposa
# Out:
#      Notice Date Effective Date Received Date  \
# 467   04/07/2020     03/13/2020    04/20/2020
# 1678  04/15/2020     03/19/2020    06/04/2020
# 1943  04/29/2020     03/22/2020    06/06/2020
# 1944  05/11/2020     03/26/2020    06/05/2020
# 1945  05/11/2020     03/26/2020    06/05/2020
# 3937  07/30/2020     08/15/2020    08/03/2020
#
#                                                 Company  \
# 467                                  Aramark - Yosemite
# 1678  Delaware North Companies Parks & Resorts atTen...
# 1943  El Portal Canyon Restaurant  dba Miner'sRoadho...
# 1944  El Portal Dining Inc dba Cedar House CanyonBar...
# 1945            El Portal Dining Inc dba Parkside Pizza
# 3937                           NatureBridge at Yosemite
#
#                         City           County  Employees     Layoff/Closure  \
# 467   Yosemite National Park  Mariposa County     1829.0   Layoff Temporary
# 1678               Fish Camp  Mariposa County      343.0  Closure Temporary
# 1943                Mariposa  Mariposa County       15.0   Layoff Temporary
# 1944               El Portal  Mariposa County        9.0   Layoff Temporary
# 1945               El Portal  Mariposa County       21.0   Layoff Temporary
# 3937  Yosemite National Park  Mariposa County       45.0   Layoff Permanent
#
#           County Orig    Year Layoff/Closure clean  Population  \
# 467   Mariposa County  2020.0     layoff temporary     17203.0
# 1678  Mariposa County  2020.0    closure temporary     17203.0
# 1943  Mariposa County  2020.0     layoff temporary     17203.0
# 1944  Mariposa County  2020.0     layoff temporary     17203.0
# 1945  Mariposa County  2020.0     layoff temporary     17203.0
# 3937  Mariposa County  2020.0     layoff permanent     17203.0
#
#                       City 2                       Company_harmonizer_cleaned  \
# 467   yosemite national park                                 ARAMARK YOSEMITE
# 1678               fish camp  DELAWARE NORTH COMPANIES PARKS RESORTS ATTENAYA
# 1943                mariposa     PORTAL CANYON RESTAURANT MINERSROADHOUSE 140
# 1944               el portal        PORTAL DINING CEDAR HOUSE CANYONBAR GRILL
# 1945               el portal                     PORTAL DINING PARKSIDE PIZZA
# 3937  yosemite national park                            NATUREBRIDGE YOSEMITE
#
#       Company_harmonizer_score  Company_harmonizer_id  \
# 467                  63.000000                  324.0
# 1678                 40.833333                 1221.0
# 1943                 28.243243                 1403.0
# 1944                 50.455446                 1404.0
# 1945                 60.484375                 1405.0
# 3937                 62.109375                 2913.0
#
#                         Company_harmonizer_standardized
# 467                                  Aramark - Yosemite
# 1678  Delaware North Companies Parks & Resorts atTen...
# 1943  El Portal Canyon Restaurant  dba Miner'sRoadho...
# 1944  El Portal Dining Inc dba Cedar House CanyonBar...
# 1945            El Portal Dining Inc dba Parkside Pizza
# 3937                           NatureBridge at Yosemite

# %%
# Fact Check that West Sacramento is most affected by Layoffs in Yolo County

Yolo = cali_2020_info[cali_2020_info['County'] == 'Yolo County']
Yolo = Yolo[Yolo['Year'] == 2020]
Yolo.groupby('City').sum()
# Out:
#                  Employees     Year  Population  Company_harmonizer_score  \
# City
# Davis                290.0  28280.0   3087000.0                831.099362
# Madison                8.0   2020.0    220500.0                 37.000000
# West Sacramento      704.0  26260.0   2866500.0                751.594183
# Winters              111.0   4040.0    441000.0                117.382040
# Woodland             197.0  12120.0   1323000.0                294.979928
#
#                  Company_harmonizer_id
# City
# Davis                          24299.0
# Madison                          820.0
# West Sacramento                33587.0
# Winters                         1301.0
# Woodland                       11322.0

# %%
## Fact-Checking how many Layoffs Driven Performance Brands had in total for 2020.

Yolo = cali_2020_info[cali_2020_info['County'] == 'Yolo County']
sum_it = Yolo[Yolo['Company_harmonizer_cleaned'] == 'Driven Performance Brands, Inc.']
sum_it.groupby('County').sum()
# Out:
# Empty DataFrame
# Columns: [Employees, Year, Population, Company_harmonizer_score, Company_harmonizer_id]
# Index: []

# %%
## Fact Check Santa Cruz County's permanent layoff figures

santa_cruz_20 = cali_2020_info[cali_2020_info['County'] == 'Santa Cruz County'] 
santa_cruz_20.groupby('County').max()
# Out:
#                   Notice Date Effective Date Received Date  \
# County
# Santa Cruz County  11/18/2020     11/23/2020    12/01/2020
#
#                                           Company         City  Employees  \
# County
# Santa Cruz County  Watsonville Community Hospital  Watsonville     1097.0
#
#                                Layoff/Closure        County Orig    Year  \
# County
# Santa Cruz County  Layoff Unknown at thistime  Santa Cruz County  2020.0
#
#                         Layoff/Closure clean  Population       City 2  \
# County
# Santa Cruz County  layoff type uncategorized    273213.0  watsonville
#
#                        Company_harmonizer_cleaned  Company_harmonizer_score  \
# County
# Santa Cruz County  WATSONVILLE COMMUNITY HOSPITAL                     100.0
#
#                    Company_harmonizer_id Company_harmonizer_standardized
# County
# Santa Cruz County                 4528.0  Watsonville Community Hospital

# %%
santa_cruz_20_perm = santa_cruz_20[santa_cruz_20['Layoff/Closure clean'] == 'layoff permanent']
santa_cruz_20_perm.groupby('County').max()

#Just extract employee field
# Out:
#                   Notice Date Effective Date Received Date  \
# County
# Santa Cruz County  10/28/2020     09/01/2020    11/16/2020
#
#                                           Company         City  Employees  \
# County
# Santa Cruz County  Watsonville Community Hospital  Watsonville      265.0
#
#                      Layoff/Closure        County Orig    Year  \
# County
# Santa Cruz County  Layoff Permanent  Santa Cruz County  2020.0
#
#                   Layoff/Closure clean  Population       City 2  \
# County
# Santa Cruz County     layoff permanent    273213.0  watsonville
#
#                        Company_harmonizer_cleaned  Company_harmonizer_score  \
# County
# Santa Cruz County  WATSONVILLE COMMUNITY HOSPITAL                     100.0
#
#                    Company_harmonizer_id Company_harmonizer_standardized
# County
# Santa Cruz County                 4528.0  Watsonville Community Hospital

# %%
santa_cruz_20_perm[santa_cruz_20_perm['Employees'] == 265.0]
# Out:
#      Notice Date Effective Date Received Date                         Company  \
# 3879  07/31/2020     09/01/2020    10/12/2020  Mount Hermon Association, Inc.
#
#         City             County  Employees    Layoff/Closure  \
# 3879  Felton  Santa Cruz County      265.0  Layoff Permanent
#
#             County Orig    Year Layoff/Closure clean  Population  City 2  \
# 3879  Santa Cruz County  2020.0     layoff permanent    273213.0  felton
#
#      Company_harmonizer_cleaned  Company_harmonizer_score  \
# 3879   MOUNT HERMON ASSOCIATION                     100.0
#
#       Company_harmonizer_id Company_harmonizer_standardized
# 3879                 2865.0   Mount Hermon Association, Inc

# %%
## No Layoffs from Mount Hermon Association, so it seems like the layoffs for the company in 2020 are not a seasonal thing

santa_cruz_19 = cali_2019_info[cali_2019_info['County'] == 'Santa Cruz County']
santa_cruz_19
# Out:
#      Notice Date Effective Date Received Date  \
# 1214  10/09/2019     12/09/2019    10/11/2019
# 1387  08/30/2019     10/31/2019    09/06/2019
# 5236  04/12/2019     06/12/2019    04/12/2019
#
#                                   Company         City             County  \
# 1214               Chaminade Resort & Spa   Santa Cruz  Santa Cruz County
# 1387              Coastline Support, Inc.   Santa Cruz  Santa Cruz County
# 5236  Spawn Mate, Inc. dba Mushroom Farms  Watsonville  Santa Cruz County
#
#       Employees     Layoff/Closure        County Orig    Year  \
# 1214       93.0   Layoff Temporary  Santa Cruz County  2019.0
# 1387       55.0  Closure Permanent  Santa Cruz County  2019.0
# 5236       82.0  Closure Permanent         Santa Cruz  2019.0
#
#      Layoff/Closure clean  Population       City 2 Company_harmonizer_cleaned  \
# 1214     layoff temporary    273213.0   santa cruz       CHAMINADE RESORT SPA
# 1387    closure permanent    273213.0   santa cruz          COASTLINE SUPPORT
# 5236    closure permanent    273213.0  watsonville  SPAWN MATE MUSHROOM FARMS
#
#       Company_harmonizer_score  Company_harmonizer_id  \
# 1214                 39.189873                  849.0
# 1387                 54.458716                  997.0
# 5236                 40.476190                 3890.0
#
#           Company_harmonizer_standardized
# 1214               Chaminade Resort & Spa
# 1387              Coastline Support, Inc.
# 5236  Spawn Mate, Inc. dba Mushroom Farms

# %%
## Looking into Butte County, which had the highest rent burden

butte = cali_2020_info[cali_2020_info['County'] == 'Butte County']
butte
# Out:
#      Notice Date Effective Date Received Date  \
# 214   11/16/2020     01/11/2021    11/23/2020
# 506   04/21/2020     04/10/2020    05/27/2020
# 1011  09/25/2020     08/19/2020    09/29/2020
# 1297  03/26/2020     03/26/2020    04/15/2020
# 1741  04/17/2020     04/12/2020    04/28/2020
# 2855  03/30/2020     03/16/2020    04/13/2020
# 3550  03/23/2020     03/23/2020    05/14/2020
# 3551  04/23/2020     04/24/2020    09/01/2020
# 4302  04/02/2020     03/24/2020    04/20/2020
# 4714  04/08/2020     03/17/2020    04/29/2020
#
#                                                 Company   City        County  \
# 214                          Adventist Health Home Care  Chico  Butte County
# 506   Associated Students of California StateUnivers...  Chico  Butte County
# 1011                                         CSU, Chico  Chico  Butte County
# 1297               Cinemark USA Inc. dba Cinemark Chico  Chico  Butte County
# 1741     Dick's Sporting Goods Inc. at Chico Store#1089  Chico  Butte County
# 2855                          Hupp Draft Services, Inc.  Chico  Butte County
# 3550                         Lulu's Fashion Lounge, LLC  Chico  Butte County
# 3551                         Lulu's Fashion Lounge, LLC  Chico  Butte County
# 4302                                  Pancakes 1702 INC  Chico  Butte County
# 4714               Restec Contractors Inc. at CSU Chico  Chico  Butte County
#
#       Employees              Layoff/Closure   County Orig    Year  \
# 214        14.0           Closure Permanent  Butte County  2020.0
# 506       660.0            Layoff Temporary  Butte County  2020.0
# 1011      446.0            Layoff Permanent  Butte County  2020.0
# 1297       46.0            Layoff Permanent  Butte County  2020.0
# 1741       28.0            Layoff Temporary  Butte County  2020.0
# 2855       93.0            Layoff Temporary  Butte County  2020.0
# 3550      213.0            Layoff Temporary  Butte County  2020.0
# 3551       78.0            Layoff Permanent  Butte County  2020.0
# 4302       45.0  Layoff Unknown at thistime  Butte County  2020.0
# 4714        8.0            Layoff Temporary  Butte County  2020.0
#
#            Layoff/Closure clean  Population City 2  \
# 214           closure permanent    219186.0  chico
# 506            layoff temporary    219186.0  chico
# 1011           layoff permanent    219186.0  chico
# 1297           layoff permanent    219186.0  chico
# 1741           layoff temporary    219186.0  chico
# 2855           layoff temporary    219186.0  chico
# 3550           layoff temporary    219186.0  chico
# 3551           layoff permanent    219186.0  chico
# 4302  layoff type uncategorized    219186.0  chico
# 4714           layoff temporary    219186.0  chico
#
#                              Company_harmonizer_cleaned  \
# 214                          ADVENTIST HEALTH HOME CARE
# 506   ASSOCIATED STUDENTS CALIFORNIA STATEUNIVERSITY...
# 1011                                          CSU CHICO
# 1297                            CINEMARK CINEMARK CHICO
# 1741               DICKS SPORTING GOODS CHICO STORE1089
# 2855                                HUPP DRAFT SERVICES
# 3550                               LULUS FASHION LOUNGE
# 3551                               LULUS FASHION LOUNGE
# 4302                                      PANCAKES 1702
# 4714                       RESTEC CONTRACTORS CSU CHICO
#
#       Company_harmonizer_score  Company_harmonizer_id  \
# 214                  77.470968                  164.0
# 506                  69.942857                  356.0
# 1011                 33.333333                  710.0
# 1297                 82.634731                  926.0
# 1741                 86.954023                 1261.0
# 2855                 34.434783                 2090.0
# 3550                 50.980392                 2591.0
# 3551                100.000000                 2591.0
# 4302                 46.494624                 3197.0
# 4714                 77.794872                 3510.0
#
#                         Company_harmonizer_standardized
# 214                 Adventist Health Home Care Services
# 506   Associated Students of California StateUnivers...
# 1011                                         CSU, Chico
# 1297               Cinemark USA Inc. dba Cinemark Chico
# 1741  Dick's Sporting Goods Inc. at Cerritos Store#1195
# 2855                          Hupp Draft Services, Inc.
# 3550                         Lulu's Fashion Lounge, LLC
# 3551                         Lulu's Fashion Lounge, LLC
# 4302                                  Pancakes 1702 INC
# 4714               Restec Contractors Inc. at CSU Chico

# %%
butte_19 = cali_2019_info[cali_2019_info['County'] == 'Butte County']
butte_19 = butte_19[butte_19['Year'] == 2019]
butte_19
# Out:
#      Notice Date Effective Date Received Date  \
# 205   01/08/2019     02/05/2019    01/25/2019
# 206   12/18/2019     02/01/2020    12/19/2019
# 1207  01/18/2019     03/17/2019    01/23/2019
# 3439  10/28/2019     12/27/2019    10/29/2019
# 3440  03/22/2019     05/24/2019    03/22/2019
# 3821  07/22/2019     09/20/2019    07/29/2019
#
#                                              Company      City        County  \
# 205                   Adventist Health Feather River  Paradise  Butte County
# 206   Adventist Health Feather River Palliative Care     Chico  Butte County
# 1207                              Cerner Corporation  Paradise  Butte County
# 3439          Lifetouch National School Studios Inc.     Chico  Butte County
# 3440          Lifetouch National School Studios Inc.     Chico  Butte County
# 3821                    Milestone Technologies, Inc.     Chico  Butte County
#
#       Employees     Layoff/Closure   County Orig    Year Layoff/Closure clean  \
# 205      1331.0  Closure Temporary  Butte County  2019.0    closure temporary
# 206         8.0  Closure Permanent  Butte County  2019.0    closure permanent
# 1207       42.0   Layoff Permanent  Butte County  2019.0     layoff permanent
# 3439      320.0  Closure Permanent  Butte County  2019.0    closure permanent
# 3440       25.0  Closure Permanent  Butte County  2019.0    closure permanent
# 3821      148.0  Closure Permanent  Butte County  2019.0    closure permanent
#
#       Population    City 2                      Company_harmonizer_cleaned  \
# 205     219186.0  paradise                  ADVENTIST HEALTH FEATHER RIVER
# 206     219186.0     chico  ADVENTIST HEALTH FEATHER RIVER PALLIATIVE CARE
# 1207    219186.0  paradise                              CERNER CORPORATION
# 3439    219186.0     chico                                LIFETOUCH SCHOOL
# 3440    219186.0     chico                                LIFETOUCH SCHOOL
# 3821    219186.0     chico                          MILESTONE TECHNOLOGIES
#
#       Company_harmonizer_score  Company_harmonizer_id  \
# 205                  77.109677                  161.0
# 206                  88.268156                  161.0
# 1207                100.000000                  842.0
# 3439                 34.958904                 2509.0
# 3440                100.000000                 2509.0
# 3821                 34.542857                 2817.0
#
#                      Company_harmonizer_standardized
# 205   Adventist Health Feather River Palliative Care
# 206   Adventist Health Feather River Palliative Care
# 1207                              Cerner Corporation
# 3439          Lifetouch National School Studios Inc.
# 3440          Lifetouch National School Studios Inc.
# 3821                    Milestone Technologies, Inc.
